# %%
import pickle
import pandas as pd
from qanta.datasets.quiz_bowl import QuestionDatabase

# %%
with open('data/100_possible_questions.pickle', 'rb') as f:
    qs = pickle.load(f)

# %%
q = qs[0]

# %%
print(q.flatten_text())
# Out:
# Prior to Stan Getz's adoption of the song, this musician played Antonio Carlos Jobim's "Desafinado" in a "musical safari" program at the Monterey Jazz Festival in 1961. One of this man's compositions was first recorded under the title "Interlude" by Sarah Vaughan, and he claimed that it was only in exchange for transcribing some of his solos that co-credit for that song was given to Frank Paparelli. He borrowed the chord structure from Paul Whiteman's "Whispering" for a track that has been used to title over a dozen of his compilation albums, "Groovin' High." In the Earl Hines band, he developed bebop with Charlie Parker. For 10 points, name this jazz musician behind "Salt Peanuts" and "A Night in Tunisia" who played with puffed cheeks and a characteristic bent trumpet.

# %%
with open('data/qb_questions.txt', 'w') as f:
    for q in qs:
        f.write(q.flatten_text())
        f.write('\n')

# %%
db = QuestionDatabase()

# %%
answers = db.all_answers().values()

# %%
with open('data/answers.txt', 'w') as f:
    for a in answers:
        f.write(a)
# Out:
# {1: 'Thomas Cole',
#  2: 'Jean-Honore Fragonard',
#  3: 'Holy Trinity (Masaccio)',
#  4: 'Rococo',
#  5: 'The Swing (painting)',
#  6: 'El Greco',
#  7: 'Aubrey Beardsley',
#  8: 'Augustus Saint-Gaudens',
#  9: 'David (Michelangelo)',
#  11: 'The Garden of Earthly Delights',
#  13: 'Self-portrait in a Convex Mirror',
#  14: 'Benjamin West',
#  15: 'Et in Arcadia ego',
#  16: 'Oath of the Horatii',
#  17: 'The Massacre at Chios',
#  18: 'The Blue Boy',
#  19: 'Nicolas Poussin',
#  207534: 'Sleep',
#  22: 'George Bellows',
#  23: 'Surrealism',
#  24: 'David Alfaro Siqueiros',
#  196633: 'Andrew Marvell',
#  26: 'Virgin of the Rocks',
#  27: 'The Disasters of War',
#  29: 'Hieronymus Bosch',
#  30: 'Pablo Picasso',
#  31: "Christ's Entry Into Brussels in 1889",
#  32: 'Primavera (painting)',
#  34: 'Berthe Morisot',
#  35: 'The Hay Wain',
#  36: 'The Swing (painting)',
#  37: 'Death of Sardanapalus',
#  38: 'Canaletto',
#  39: 'The Birth of Venus (Botticelli)',
#  40: 'Kazimir Malevich',
#  41: 'Salisbury Cathedral',
#  42: 'The Tempest (Giorgione)',
#  43: 'Fresco',
#  44: 'Marc Chagall',
#  45: 'The Rape of the Sabine Women',
#  46: 'Peter Paul Rubens',
#  47: 'The Death of Marat',
#  48: 'Gentile Bellini',
#  49: 'Olympia (Manet)',
#  51: 'Georges Seurat',
#  52: 'The Last Supper (Leonardo da Vinci)',
#  53: 'Modern Painters',
#  54: "The Painter's Studio",
#  55: 'Oath of the Horatii',
#  56: 'The Feast of the Gods',
#  57: 'Benvenuto Cellini',
#  59: 'Primavera (painting)',
#  61: 'Gustave Courbet',
#  62: 'Alphonse Mucha',
#  63: 'Ansel Adams',
#  65: 'Francisco Goya',
#  66: 'Henry Fuseli',
#  67: 'Kazimir Malevich',
#  68: 'Benjamin West',
#  69: 'The Scapegoat (painting)',
#  70: 'The Embarkation for Cythera',
#  71: 'Pre-Raphaelite Brotherhood',
#  72: 'J. M. W. Turner',
#  74: 'Diego Rivera',
#  75: 'Rene Magritte',
#  76: 'Albrecht Durer',
#  77: 'Constructivism (art)',
#  78: 'Melencolia I',
#  79: 'Thomas Cole',
#  80: 'Paul Cezanne',
#  81: 'Eugene Delacroix',
#  82: 'Isenheim Altarpiece',
#  83: 'Henri Rousseau',
#  85: 'Pieter Bruegel the Elder',
#  86: 'The Hay Wain',
#  87: 'The Swing (painting)',
#  88: 'John Ruskin',
#  89: 'Primavera (painting)',
#  90: 'Henri Matisse',
#  91: 'Pierre-Auguste Renoir',
#  196700: 'Compromise of 1850',
#  93: 'The Tempest (Giorgione)',
#  94: 'The Kiss (Klimt)',
#  95: 'Claude Monet',
#  96: 'The Kiss (Klimt)',
#  97: 'Charles Willson Peale',
#  98: 'Caspar David Friedrich',
#  99: 'Venus',
#  196709: 'Robert Walpole',
#  102: 'The Tribute Money (Masaccio)',
#  103: 'Ophelia (painting)',
#  104: 'The Night Cafe',
#  105: 'Aubrey Beardsley',
#  107: 'Hans Holbein the Younger',
#  108: 'Caravaggio',
#  109: 'Anthony van Dyck',
#  110: 'I and the Village',
#  111: 'The Gross Clinic',
#  205136: 'Dylan Thomas',
#  196721: 'The Charterhouse of Parma',
#  114: 'The Garden of Earthly Delights',
#  115: 'Paul Klee',
#  196724: 'A Passage to India',
#  118: 'Frans Hals',
#  119: 'John Singer Sargent',
#  121: 'Liberty Leading the People',
#  122: 'Georges de La Tour',
#  123: 'Suzanne Valadon',
#  124: 'Diego Rivera',
#  126: 'Dante Gabriel Rossetti',
#  128: 'Edward Hopper',
#  129: 'Jacques-Louis David',
#  130: 'The Last Judgment (Michelangelo)',
#  131: 'The Gross Clinic',
#  132: 'Sandro Botticelli',
#  133: 'The School of Athens',
#  134: 'Michelangelo',
#  198590: 'Titration',
#  136: 'Winged Victory of Samothrace',
#  137: 'Georges Seurat',
#  196746: 'United States presidential election, 1876',
#  139: 'El Greco',
#  140: 'Hudson River School',
#  141: 'Liberty Leading the People',
#  142: 'The Ambassadors (Holbein)',
#  143: 'Ghent Altarpiece',
#  144: 'Joan Miro',
#  147: 'The Potato Eaters',
#  149: 'Albrecht Durer',
#  150: 'Watson and the Shark',
#  151: 'De Stijl',
#  152: 'Fountain (Duchamp)',
#  153: 'Piet Mondrian',
#  154: 'Antonio da Correggio',
#  156: 'The Garden of Earthly Delights',
#  158: 'Grandma Moses',
#  159: 'Francis Bacon (artist)',
#  160: 'Washington Crossing the Delaware',
#  161: 'Paolo Veronese',
#  162: 'Bridge',
#  196635: 'Genetic drift',
#  164: 'The Hunters in the Snow',
#  207558: 'Parks and Recreation',
#  166: 'Albert Bierstadt',
#  167: 'Thomas Cole',
#  168: 'The Raft of the Medusa',
#  169: 'Giorgio Vasari',
#  170: 'Arnolfini Portrait',
#  171: 'Donatello',
#  172: 'I Saw the Figure 5 in Gold',
#  173: 'American Gothic',
#  174: 'Edgar Degas',
#  196637: 'First Battle of Bull Run',
#  176: 'The Hay Wain',
#  177: 'Pablo Picasso',
#  178: 'Las Meninas',
#  179: 'Vincent van Gogh',
#  181: 'Rococo',
#  182: 'Eugene Delacroix',
#  183: 'Laughing Cavalier',
#  184: 'A Sunday Afternoon on the Island of La Grande Jatte',
#  185: "Christina's World",
#  186: 'Nicolas Poussin',
#  187: 'Gustav Klimt',
#  188: 'Brancacci Chapel',
#  189: 'Edouard Manet',
#  190: 'The Raft of the Medusa',
#  191: 'The Death of Socrates',
#  192: 'The Hay Wain',
#  196640: 'Battle of Tours',
#  195: 'The Four Apostles',
#  196: 'Diego Velazquez',
#  197: 'Winslow Homer',
#  198: "Christina's World",
#  199: 'Albrecht Altdorfer',
#  207564: 'Magnetic field',
#  202: 'Hague School',
#  196642: 'Hermann Hesse',
#  206: 'Fra Angelico',
#  208: 'Death of Sardanapalus',
#  209: 'Meindert Hobbema',
#  210: 'The Calling of St Matthew (Caravaggio)',
#  211: 'Jean-Francois Millet',
#  212: 'The Feast of the Gods',
#  213: 'The Starry Night',
#  214: 'Leonardo da Vinci',
#  215: 'Portrait of Madame X',
#  216: 'Le Déjeuner sur l’herbe',
#  217: 'The Tribute Money (Masaccio)',
#  218: 'Ghent Altarpiece',
#  219: 'Las Meninas',
#  220: 'Madonna with the Long Neck',
#  221: "Les Demoiselles d'Avignon",
#  223: 'Theodore Gericault',
#  224: 'View of Delft',
#  226: 'The Burial of the Count of Orgaz',
#  227: 'Paul Gauguin',
#  228: 'The Birth of Venus (Botticelli)',
#  229: 'A Sunday Afternoon on the Island of La Grande Jatte',
#  230: 'Portrait of Madame X',
#  231: 'Frans Hals',
#  233: 'John Singleton Copley',
#  234: 'The Ambassadors (Holbein)',
#  235: 'Andrea del Sarto',
#  236: 'Edvard Munch',
#  237: 'Las Meninas',
#  238: 'Amedeo Modigliani',
#  239: 'Joan Miro',
#  240: 'Mark Rothko',
#  241: 'Nicolas Poussin',
#  242: 'Der Blaue Reiter',
#  243: 'The Heart of the Andes',
#  244: 'Olympia (Manet)',
#  245: 'Miracle of the Slave (Tintoretto)',
#  246: 'Marc Chagall',
#  247: 'Holy Trinity (Masaccio)',
#  248: 'Flight into Egypt',
#  249: 'Die Brucke',
#  250: 'The Third-Class Carriage',
#  251: 'The Ambassadors (Holbein)',
#  196860: 'Refractive index',
#  196861: 'Prussia',
#  254: 'The Embarkation for Cythera',
#  255: 'Landscape with the Fall of Icarus',
#  256: 'The Hay Wain',
#  257: 'Watson and the Shark',
#  258: "Les Demoiselles d'Avignon",
#  259: 'Antonio da Correggio',
#  260: 'The Rape of the Sabine Women',
#  261: 'Rococo',
#  262: 'Venus de Milo',
#  263: 'Caravaggio',
#  264: 'The Raft of the Medusa',
#  265: 'Las Meninas',
#  266: 'Nighthawks',
#  267: 'Jan Steen',
#  196876: 'Tom Stoppard',
#  269: 'Black Paintings',
#  270: 'Titian',
#  271: "Christina's World",
#  272: 'Paolo Veronese',
#  273: 'Paul Cézanne',
#  274: 'Paul Gauguin',
#  275: 'Tempera',
#  276: 'The Last Judgment (Michelangelo)',
#  277: 'Pieter Bruegel the Elder',
#  278: 'Henri Rousseau',
#  279: 'Pierre-Auguste Renoir',
#  280: 'Venice',
#  196889: 'George Gershwin',
#  282: 'The Persistence of Memory',
#  283: 'J. M. W. Turner',
#  284: 'Primavera (painting)',
#  285: 'The Swing (painting)',
#  286: 'Venus of Urbino',
#  288: 'Expulsion from the Garden of Eden',
#  289: 'The Nightmare',
#  290: 'Frederic Edwin Church',
#  291: 'Et in Arcadia ego',
#  292: 'Oskar Kokoschka',
#  293: 'John Constable',
#  196902: 'Milton Friedman',
#  295: 'Kazimir Malevich',
#  296: 'Olympia (Manet)',
#  196905: 'John Keats',
#  298: 'Umberto Boccioni',
#  299: 'Ben Shahn',
#  300: 'Constantin Brancusi',
#  301: 'The Triumph of Death',
#  302: 'Virgin of the Rocks',
#  196911: 'Søren Kierkegaard',
#  304: 'Domenichino',
#  305: 'Caspar David Friedrich',
#  306: 'Benvenuto Cellini',
#  307: 'Rain, Steam and Speed – The Great Western Railway',
#  308: 'Thomas Gainsborough',
#  196917: 'Zoroastrianism',
#  310: 'Mystical marriage of Saint Catherine',
#  311: 'The Agnew Clinic',
#  196920: 'Capacitance',
#  313: 'The Apotheosis of Homer (Ingres)',
#  314: 'The Anatomy Lesson of Dr. Nicolaes Tulp',
#  315: 'The Great Wave off Kanagawa',
#  316: "Christ's Entry Into Brussels in 1889",
#  317: 'Tintoretto',
#  318: 'The Gulf Stream (painting)',
#  196661: 'Paraguayan War',
#  321: 'The Kiss (Klimt)',
#  322: 'Landscape with the Fall of Icarus',
#  323: 'Bartolome Esteban Murillo',
#  324: 'Jean-Baptiste-Simeon Chardin',
#  325: 'Aubrey Beardsley',
#  326: 'Where Do We Come From? What Are We? Where Are We Going?',
#  327: 'Bronzino',
#  328: 'Thomas Eakins',
#  329: 'John Everett Millais',
#  330: 'De Stijl',
#  331: 'Nazarene movement',
#  332: 'The Night Watch',
#  333: 'The Swing (painting)',
#  334: 'Jose Clemente Orozco',
#  196943: 'Henry Clay',
#  196944: 'Billy Budd',
#  196945: 'Arthur Schopenhauer',
#  339: 'Laughing Cavalier',
#  340: 'Antoine Watteau',
#  341: 'Anthony van Dyck',
#  342: 'Francis Bacon (artist)',
#  343: 'De Stijl',
#  344: 'The Burial of the Count of Orgaz',
#  196953: 'Second Boer War',
#  346: 'The Sleeping Gypsy',
#  347: "The Painter's Studio",
#  348: 'Marcel Duchamp',
#  349: 'Jose Clemente Orozco',
#  350: 'Pierre-Auguste Renoir',
#  351: 'Las Meninas',
#  352: 'Francisco Goya',
#  353: 'Madonna with the Long Neck',
#  354: 'Joan Miro',
#  355: 'Adoration of the Magi (Gentile da Fabriano)',
#  356: 'Frederic Edwin Church',
#  357: 'The Birth of Venus (Bouguereau)',
#  358: 'Madonna with the Long Neck',
#  359: 'Venus of Urbino',
#  360: 'Gustave Courbet',
#  361: 'James Abbott McNeill Whistler',
#  362: 'Henri Matisse',
#  363: 'Le Déjeuner sur l’herbe',
#  364: 'The Last Supper (Leonardo da Vinci)',
#  365: 'The Night Watch',
#  366: 'Johannes Vermeer',
#  367: 'Watson and the Shark',
#  368: 'De Stijl',
#  369: 'Jackson Pollock',
#  370: 'The Gross Clinic',
#  371: 'Guernica (painting)',
#  196980: 'Gestalt psychology',
#  373: 'Francisco Goya',
#  374: 'Edvard Munch',
#  375: 'William Hogarth',
#  376: "Christina's World",
#  377: 'Caravaggio',
#  196986: 'The Four Seasons (Vivaldi)',
#  380: 'The Barque of Dante',
#  381: 'Sacred and Profane Love',
#  382: 'Charles Willson Peale',
#  383: 'The Colossus (painting)',
#  384: 'Ilya Repin',
#  385: 'The Nightmare',
#  386: 'The Kiss (Klimt)',
#  196995: 'Leo Tolstoy',
#  196996: 'Franz Boas',
#  390: 'Arnolfini Portrait',
#  391: 'Washington Crossing the Delaware',
#  392: 'Robert Motherwell',
#  393: 'The Garden of Earthly Delights',
#  394: 'Jean-Honoré Fragonard',
#  395: 'Edward Hopper',
#  396: 'RainRain, Steam and Speed – The Great Western Railway',
#  397: "Christina's World",
#  398: 'The Persistence of Memory',
#  399: 'The Death of Marat',
#  400: 'Venus of Urbino',
#  401: 'Pierre-Auguste Renoir',
#  402: 'The Anatomy Lesson of Dr. Nicolaes Tulp',
#  403: 'Olympia (Manet)',
#  405: 'Primavera (painting)',
#  406: 'Black Paintings',
#  197015: 'René Descartes',
#  409: 'Edvard Munch',
#  410: 'James Abbott McNeill Whistler',
#  411: 'Paolo Uccello',
#  412: 'The Massacre at Chios',
#  413: 'Laughing Cavalier',
#  414: 'Joshua Reynolds',
#  197023: 'United Nations',
#  416: 'Franz Marc',
#  417: 'The Voyage of Life',
#  418: 'The Last Supper (Leonardo da Vinci)',
#  419: 'David Hockney',
#  420: 'Aubrey Beardsley',
#  196678: 'Love in the Time of Cholera',
#  422: 'Gustave Caillebotte',
#  423: 'The Country of the Pointed Firs',
#  197032: 'Ferromagnetism',
#  425: 'John Singleton Copley',
#  426: 'Giorgione',
#  427: 'Venus',
#  197036: 'A Portrait of the Artist as a Young Man',
#  197037: 'Sisyphus',
#  430: 'Paul Signac',
#  197040: 'The Hollow Men',
#  433: 'The Feast in the House of Levi',
#  434: 'Giorgio de Chirico',
#  197043: 'Zen',
#  436: 'Merode Altarpiece',
#  437: 'Max Ernst',
#  438: 'The Lady of Shalott (painting)',
#  439: 'Jean Auguste Dominique Ingres',
#  440: 'Jean-Francois Millet',
#  441: 'Benvenuto Cellini',
#  443: 'The Women of Algiers',
#  197052: 'Attila',
#  196682: 'Zora Neale Hurston',
#  446: 'John Singer Sargent',
#  447: 'Madonna with the Long Neck',
#  448: 'Tintoretto',
#  449: 'Gian Lorenzo Bernini',
#  197058: 'Henrik Ibsen',
#  197059: 'Teapot Dome scandal',
#  452: 'Salvador Dali',
#  453: 'John Constable',
#  454: 'Grant Wood',
#  455: 'Benvenuto Cellini',
#  456: 'The Ambassadors (Holbein)',
#  457: 'The Death of Socrates',
#  197066: 'John Steinbeck',
#  197067: 'X chromosome',
#  460: 'Rembrandt',
#  461: 'Dog',
#  462: 'Albrecht Durer',
#  463: 'El Greco',
#  464: 'A Burial At Ornans',
#  465: 'Jan van Eyck',
#  466: 'I and the Village',
#  197075: 'Brazil',
#  468: 'Dada',
#  196686: 'Franz Schubert',
#  470: 'Andrea Mantegna',
#  471: 'Edvard Munch',
#  472: 'Jean-Francois Millet',
#  473: 'James Ensor',
#  474: 'Max Schmitt in a Single Scull',
#  476: 'Nicolas Poussin',
#  477: 'Paul Cezanne',
#  478: 'Masaccio',
#  479: 'Kindred Spirits',
#  480: 'Paul Klee',
#  481: 'The Burial of the Count of Orgaz',
#  197090: 'Jason',
#  483: 'Gustav Klimt',
#  484: 'Venus',
#  485: 'A Burial At Ornans',
#  486: 'Norman Rockwell',
#  487: 'John Everett Millais',
#  488: 'Parmigianino',
#  489: 'Pieter Bruegel the Elder',
#  490: 'Luncheon of the Boating Party',
#  491: 'Ashcan School',
#  492: 'Dorothea Lange',
#  493: 'Henri Rousseau',
#  197102: 'Maine',
#  495: 'Melencolia I',
#  496: "The Painter's Studio",
#  497: 'Suprematism',
#  498: 'Ghent Altarpiece',
#  500: 'Jean Auguste Dominique Ingres',
#  501: 'The Lady of Shalott (painting)',
#  502: 'Liberty Leading the People',
#  503: 'Holy Trinity (Masaccio)',
#  197112: 'Tree (graph theory)',
#  197113: 'Zambezi',
#  506: 'The Death of General Wolfe',
#  507: 'The Anatomy Lesson of Dr. Nicolaes Tulp',
#  508: 'Ophelia (painting)',
#  509: 'David Alfaro Siqueiros',
#  510: 'Gustave Courbet',
#  511: 'Alberto Giacometti',
#  512: 'Kindred Spirits',
#  513: 'Antonio da Correggio',
#  514: 'Antoine Watteau',
#  515: 'Paolo Veronese',
#  516: 'Jean-Baptiste-Simeon Chardin',
#  517: 'Rokeby Venus',
#  197126: 'X-ray',
#  519: 'Orphism (art)',
#  520: 'Et in Arcadia ego',
#  521: 'Robert Henri',
#  522: 'Godfrey Kneller',
#  523: 'The Three Philosophers',
#  524: 'Myron',
#  525: 'Max Schmitt in a Single Scull',
#  526: 'Conversion on the Way to Damascus',
#  527: 'Ghent Altarpiece',
#  528: 'Hudson River School',
#  529: 'Berlin Wall',
#  530: 'The Martyrdom of Saint Matthew (Caravaggio)',
#  532: 'Jackson Pollock',
#  533: 'Henri Matisse',
#  197142: 'Wolfgang Amadeus Mozart',
#  535: 'Constantin Brancusi',
#  536: 'The School of Athens',
#  537: 'Anthony van Dyck',
#  538: 'Lemuel Gulliver',
#  197147: "Uncle Tom's Cabin",
#  540: 'Henry II of France',
#  541: 'Landscape with the Fall of Icarus',
#  542: 'Seagram Building',
#  543: 'Babur',
#  545: 'Salvador Dalí',
#  197154: 'Sophocles',
#  547: 'Thomas Eakins',
#  548: 'Hungary',
#  549: 'Edvard Munch',
#  550: 'Paul Cézanne',
#  551: 'Kazimir Malevich',
#  552: 'Jean Auguste Dominique Ingres',
#  553: 'Andy Warhol',
#  554: 'Piet Mondrian',
#  555: 'Man Ray',
#  556: 'Hieronymus Bosch',
#  197165: 'Burma',
#  558: 'Andrew Wyeth',
#  559: 'Pierre-Auguste Renoir',
#  197168: 'The Canterbury Tales',
#  561: 'Giorgione',
#  562: 'James Ensor',
#  563: 'Paul Gauguin',
#  564: 'Dorothea Lange',
#  565: 'Albrecht Durer',
#  566: 'Marc Chagall',
#  567: 'The Anatomy Lesson of Dr. Nicolaes Tulp',
#  197176: 'Speciation',
#  569: 'Nicolas Poussin',
#  570: 'Diego Velazquez',
#  571: 'Russia',
#  572: 'Theodore Gericault',
#  573: 'John Everett Millais',
#  574: 'Sistine Chapel ceiling',
#  575: "The Painter's Studio",
#  197184: 'Center of mass',
#  577: 'Paolo Veronese',
#  578: 'Asher Brown Durand',
#  579: 'The Calling of St Matthew (Caravaggio)',
#  580: 'Peter Paul Rubens',
#  581: 'Thomas Cole',
#  582: 'Praxiteles',
#  583: 'Titian',
#  585: 'Watson and the Shark',
#  586: 'Umberto Boccioni',
#  587: 'Parmigianino',
#  588: 'The Daughters of Edward Darley Boit',
#  589: 'Der Rosenkavalier',
#  590: 'Maurice Ravel',
#  591: 'Cavalleria rusticana',
#  592: 'Mstislav Rostropovich',
#  593: 'Symphony No. 104 (Haydn)',
#  594: 'In the Hall of the Mountain King',
#  595: 'Henry Purcell',
#  596: 'Paul Dukas',
#  597: 'Der Freischütz',
#  598: 'Robert Schumann',
#  197207: 'Uranium',
#  600: 'Domenico Scarlatti',
#  601: 'Jose Carreras',
#  602: 'The Mikado',
#  197211: 'Xylem',
#  604: 'La donna e mobile',
#  605: 'Pagliacci',
#  606: 'Der Tod und das Mädchen',
#  607: 'Hector Berlioz',
#  608: 'La Fenice',
#  609: 'Der Schauspieldirektor',
#  610: 'Samuel Barber',
#  611: 'Chanson de geste',
#  612: 'Fidelio',
#  613: 'Ignacy Jan Paderewski',
#  614: 'Concerto',
#  615: 'Bassoon',
#  616: 'Petrushka (ballet)',
#  617: 'Zither',
#  618: 'Bela Bartok',
#  619: 'Gustav Mahler',
#  620: 'Francis Poulenc',
#  197229: 'Atlas (mythology)',
#  622: 'Violin Concerto (Berg)',
#  623: 'Eugene Ormandy',
#  624: 'Claudio Monteverdi',
#  625: 'Nabucco',
#  626: 'Giacomo Puccini',
#  627: 'Les Huguenots',
#  197236: 'Borneo',
#  629: 'Ma vlast',
#  630: 'Germaine Tailleferre',
#  631: 'Erik Satie',
#  632: 'Paul Bunyan (operetta)',
#  197241: 'The Last Supper (Leonardo da Vinci)',
#  634: 'Three Places in New England',
#  635: 'Cesar Franck',
#  636: 'Hugo Wolf',
#  637: 'Suite (music)',
#  638: 'The Four Seasons (Vivaldi)',
#  197247: 'F. Scott Fitzgerald',
#  640: 'Gamelan',
#  641: 'Trumpet',
#  642: 'Robert Schumann',
#  643: 'Academic Festival Overture',
#  197252: 'Inflation',
#  645: 'Erik Satie',
#  646: 'Symphony No. 6 (Tchaikovsky)',
#  647: 'Jenny Lind',
#  648: 'Pictures at an Exhibition',
#  649: 'Undine (Lortzing)',
#  650: 'Cantata',
#  651: 'Franz Liszt',
#  197260: 'James Joyce',
#  653: 'Norma (opera)',
#  654: 'Danse Macabre',
#  655: 'Frederic Chopin',
#  197264: 'Pendulum',
#  657: 'Diabelli Variations',
#  658: 'Nikolai Rimsky-Korsakov',
#  659: 'Carl Nielsen',
#  661: 'Modest Mussorgsky',
#  662: 'Semyon Kotko',
#  663: 'The Three-Cornered Hat',
#  664: 'Jules Massenet',
#  665: 'Jenufa',
#  666: 'Il trovatore',
#  667: 'Ma vlast',
#  197276: 'Lake Baikal',
#  669: 'Das Lied von der Erde',
#  670: 'Charles Gounod',
#  671: 'Frederick Delius',
#  672: 'Giselle',
#  673: 'Rigoletto',
#  674: 'Rhapsody in Blue',
#  675: 'Giuseppe Verdi',
#  676: 'Aram Khachaturian',
#  677: 'Gustav Mahler',
#  678: 'Johannes Brahms',
#  679: 'Dies Irae',
#  680: 'The Snow Maiden',
#  681: 'Bolero',
#  682: 'Brandenburg concertos',
#  683: 'Edward Elgar',
#  684: 'Rigoletto',
#  685: 'Mikhail Glinka',
#  686: 'Felix Mendelssohn',
#  687: 'Samuel Barber',
#  688: 'Bolero',
#  689: 'A Little Night Music',
#  690: 'Peter Grimes',
#  691: 'Arnold Schoenberg',
#  692: 'Siegfried (opera)',
#  693: 'Goldberg Variations',
#  694: 'La boheme',
#  695: 'Antonin Dvorak',
#  696: 'Die Meistersinger von Nürnberg',
#  697: 'Rhapsody on a Theme of Paganini',
#  698: 'Carmina Burana (Orff)',
#  699: 'Carl Maria von Weber',
#  700: 'Camille Saint-Saëns',
#  701: 'Der Tod und das Mädchen',
#  702: 'Alban Berg',
#  703: 'Cavalleria rusticana',
#  704: 'Lucia di Lammermoor',
#  705: 'Carmen',
#  706: 'Symphony No. 94 (Haydn)',
#  707: 'Cosi fan tutte',
#  708: 'Un ballo in maschera',
#  196726: 'Chief Joseph',
#  710: 'Kurt Weill',
#  197319: 'Porgy and Bess',
#  713: 'Bolero',
#  714: 'Semiramide',
#  715: 'Peter Grimes',
#  716: "Till Eulenspiegel's Merry Pranks",
#  207650: 'The Song of Roland',
#  718: 'La mer (Debussy)',
#  719: 'Requiem',
#  720: 'Wynton Marsalis',
#  721: 'Pictures at an Exhibition',
#  722: 'Edvard Grieg',
#  723: 'A Little Night Music',
#  724: 'The Hebrides (overture)',
#  725: 'Jean-Philippe Rameau',
#  726: 'Louis Armstrong',
#  727: 'La Gioconda (opera)',
#  728: 'Missa solemnis (Beethoven)',
#  729: 'Edvard Grieg',
#  730: 'Giovanni Battista Pergolesi',
#  731: 'Einstein on the Beach',
#  732: 'Leo Delibes',
#  733: 'The Marriage of Figaro',
#  734: 'Paul Hindemith',
#  735: 'John Coltrane',
#  736: 'Titan (Jean Paul novel)',
#  197345: 'Catch-22',
#  738: 'Enigma Variations',
#  739: '1812 Overture',
#  740: 'The Marriage of Figaro',
#  741: 'Johann Pachelbel',
#  742: 'Verklarte Nacht',
#  743: 'Yo-Yo Ma',
#  744: 'Franz Schubert',
#  745: 'John Cage',
#  746: 'Carmen',
#  747: 'Gustav Holst',
#  748: 'Antonio Vivaldi',
#  749: 'Richard Strauss',
#  750: 'The Nutcracker',
#  751: 'Leonard Bernstein',
#  752: 'Symphonie fantastique',
#  753: 'Scott Joplin',
#  754: 'Finlandia',
#  755: 'Academic Festival Overture',
#  756: 'The Sleeping Beauty (ballet)',
#  197365: 'Jean-Jacques Rousseau',
#  758: 'Peer Gynt',
#  759: 'Samuel Barber',
#  760: 'Manuel de Falla',
#  761: 'Meistersinger',
#  763: 'Pastoral Concert',
#  764: 'The Tales of Hoffmann',
#  765: 'Symphony No. 94 (Haydn)',
#  766: 'Ruslan and Lyudmila (opera)',
#  767: 'Franz Schubert',
#  768: 'Enigma Variations',
#  769: 'Verklarte Nacht',
#  770: 'Pictures at an Exhibition',
#  771: 'Missa solemnis (Beethoven)',
#  772: 'Darius Milhaud',
#  773: 'A (musical note)',
#  775: 'Academic Festival Overture',
#  776: 'Georges Bizet',
#  777: 'Manon',
#  778: 'Dieterich Buxtehude',
#  779: 'Les Patineurs (waltz)',
#  197388: 'Fourth Crusade',
#  783: 'Erik Satie',
#  784: 'Hungarian Rhapsodies',
#  785: 'The Golden Cockerel',
#  787: 'Verklarte Nacht',
#  197396: 'Robert E. Lee',
#  789: 'Vincenzo Bellini',
#  790: 'The Art of Fugue',
#  791: 'Anton Bruckner',
#  792: 'Satyagraha (opera)',
#  793: 'William Tell (opera)',
#  794: 'Pictures at an Exhibition',
#  795: 'Sonata',
#  796: 'Sonata (Moonlight)',
#  797: 'Pomp and Circumstance Marches',
#  798: 'Don Giovanni',
#  799: 'Jean-Baptiste Lully',
#  800: 'The Marriage of Figaro',
#  801: 'Harp',
#  802: 'Frederic Chopin',
#  803: 'Aida',
#  804: 'Antonin Dvorak',
#  805: 'Rhapsody on a Theme of Paganini',
#  806: 'Etudes (Chopin)',
#  807: 'La Cenerentola',
#  808: 'Carl Maria von Weber',
#  809: 'Carmen',
#  810: 'Rigoletto',
#  811: 'Thelonious Monk',
#  812: 'Rhapsody on a Theme of Paganini',
#  813: 'Wozzeck',
#  815: 'Gaetano Donizetti',
#  816: 'Turandot',
#  817: 'Afternoon of a Faun (Nijinsky)',
#  818: 'Enigma Variations',
#  819: 'Robert Schumann',
#  820: 'The Blue Danube',
#  821: 'Johann Sebastian Bach',
#  822: 'Unfinished symphony',
#  823: 'La fanciulla del West',
#  824: 'La mer (Debussy)',
#  825: 'Engelbert Humperdinck',
#  198613: 'Prophase',
#  827: 'Fidelio',
#  828: '1812 Overture',
#  829: 'Arrigo Boito',
#  197438: 'The Tale of Genji',
#  831: 'Robert the Devil (Gilbert)',
#  832: 'Bachianas Brasileiras',
#  197441: 'Federico Garcia Lorca',
#  834: 'Pelleas et Melisande (Faure)',
#  835: 'An American in Paris',
#  207670: 'Oscar Wilde',
#  838: 'Maurice Ravel',
#  840: 'Benjamin Britten',
#  841: 'The Open Boat',
#  842: 'Rhapsody (music)',
#  843: 'London',
#  844: 'Cor anglais',
#  845: 'La traviata',
#  846: 'Brandenburg concertos',
#  847: 'Rhapsody in Blue',
#  848: 'Fugue',
#  849: 'Nocturne',
#  850: 'Edvard Grieg',
#  851: 'Unfinished symphony',
#  852: 'Claudio Monteverdi',
#  853: 'Bolero',
#  854: 'Swan Lake',
#  855: 'Edward Elgar',
#  856: 'Dido and Aeneas',
#  857: 'Bedrich Smetana',
#  858: 'Franz Liszt',
#  859: 'Lohengrin (opera)',
#  860: 'Symphony No. 3 (Beethoven)',
#  861: 'Oratorio',
#  862: 'Eroica (2003 film)',
#  863: 'Symphony No. 8 (Mahler)',
#  864: 'Charles Ives',
#  865: 'Einstein on the Beach',
#  866: 'Ottorino Respighi',
#  867: 'Symphony No. 2 (Mahler)',
#  868: 'Faust (opera)',
#  869: 'Sergei Rachmaninoff',
#  870: 'Bedrich Smetana',
#  871: 'Enigma Variations',
#  197481: 'Madame Bovary',
#  197482: 'Operation Overlord',
#  875: '1812 Overture',
#  876: 'Rogier van der Weyden',
#  877: 'Pelleas and Melisande',
#  878: 'La traviata',
#  879: 'Maurice Ravel',
#  880: "The Young Person's Guide to the Orchestra",
#  881: 'The Love for Three Oranges',
#  882: 'Virgil Thomson',
#  883: 'The Creation (Haydn)',
#  885: 'Adolphe Adam',
#  886: 'Symphony No. 8 (Mahler)',
#  887: 'Trout Quintet',
#  888: 'Johann Pachelbel',
#  889: 'Johannes Brahms',
#  890: "Belshazzar's Feast (Sibelius)",
#  891: 'Gabriel Faure',
#  197500: 'Quebec',
#  893: 'Scheherazade (Rimsky-Korsakov)',
#  197502: 'Gravity',
#  895: 'Les Troyens',
#  896: 'Gian Carlo Menotti',
#  897: 'La sonnambula',
#  898: 'Das Lied von der Erde',
#  899: 'Frederick Delius',
#  900: 'Robert Schumann',
#  901: 'The Carnival of the Animals',
#  902: 'Johannes Brahms',
#  903: 'Pictures at an Exhibition',
#  197512: 'Wars of the Roses',
#  905: 'Gaetano Donizetti',
#  906: 'Swan Lake',
#  907: 'Igor Stravinsky',
#  908: 'Frederic Chopin',
#  909: 'A Little Night Music',
#  910: 'Turandot (Busoni)',
#  911: 'Antonio Vivaldi',
#  912: 'Samuel Barber',
#  913: 'Pagliacci',
#  914: 'Franz Liszt',
#  915: 'Gioachino Rossini',
#  917: 'Symphony',
#  918: 'Giselle',
#  919: 'Valkyrie',
#  920: 'Claude Debussy',
#  921: 'Siegfried (opera)',
#  922: 'Franz Schubert',
#  923: 'Giuseppe Verdi',
#  924: 'Alban Berg',
#  925: 'Charles Gounod',
#  926: 'Songs Without Words',
#  927: 'The Planets',
#  928: 'Akhnaten (opera)',
#  929: 'Lucia di Lammermoor',
#  931: 'Camille Saint-Saëns',
#  932: 'Antonin Dvorak',
#  933: 'La fanciulla del West',
#  934: 'Turandot',
#  935: 'Thomas Tallis',
#  936: 'Petrushka (ballet)',
#  937: 'Dmitri Shostakovich',
#  197546: 'Leonardo da Vinci',
#  939: 'Bolero',
#  941: 'Te Deum (Bruckner)',
#  942: 'Ballade (classical music)',
#  943: 'Richard Strauss',
#  944: 'Violin Sonatas, KV 6-9 (Mozart)',
#  945: 'Clarinet',
#  946: 'Claude Debussy',
#  947: 'Paul Hindemith',
#  948: 'Carl Nielsen',
#  949: 'Arnold Schoenberg',
#  197558: 'Roanoke Colony',
#  951: 'Luigi Boccherini',
#  952: 'Symphony',
#  954: 'Jean-Philippe Rameau',
#  955: 'Ignacy Jan Paderewski',
#  956: 'Antonio Salieri',
#  957: 'Toccata and Fugue in D minor, BWV 565',
#  958: 'Hungarian Rhapsodies',
#  959: 'Claude Debussy',
#  960: 'Franz Schubert',
#  961: 'Faust (opera)',
#  962: 'Christoph Willibald Gluck',
#  963: 'Nocturnes (Chopin)',
#  197572: 'Beowulf',
#  965: 'Violin Sonata No. 9 (Beethoven)',
#  197574: 'Victor Hugo',
#  967: 'Symphony No. 2 (Mahler)',
#  968: 'The Merry Widow',
#  969: 'The Unanswered Question',
#  970: 'Gyorgy Ligeti',
#  971: 'Clarinet',
#  972: 'Symphony in C major (Wagner)',
#  973: 'The Art of Fugue',
#  974: 'Cosi fan tutte',
#  975: 'Quatuor pour la fin du temps',
#  976: 'Lohengrin (opera)',
#  977: 'Violin Concerto (Mendelssohn)',
#  978: 'The Firebird',
#  979: 'The Queen of Spades (opera)',
#  980: 'Frederick Delius',
#  981: 'Cosi fan tutte',
#  982: 'Brandenburg concertos',
#  983: 'Gretchen am Spinnrade',
#  984: 'Eroica (1949 film)',
#  985: 'Bedrich Smetana',
#  986: 'Harold en Italie',
#  987: 'Sea',
#  988: 'George Gershwin',
#  197597: 'Simon Bolivar',
#  990: 'Nabucco',
#  991: 'John Adams (composer)',
#  992: 'Rigoletto',
#  993: 'Anton Bruckner',
#  994: 'Symphony No. 7 (Shostakovich)',
#  995: 'Paul Hindemith',
#  996: 'La traviata',
#  997: 'Charles Ives',
#  998: 'Tuba',
#  999: 'Claudio Monteverdi',
#  1000: 'Romeo and Juliet (Tchaikovsky)',
#  1001: 'Arnold Schoenberg',
#  197610: 'Leo Tolstoy',
#  1003: 'Four Saints in Three Acts',
#  1004: 'Bela Bartok',
#  1005: 'Don Giovanni',
#  1006: 'Giovanni Pierluigi da Palestrina',
#  1007: 'Symphony No. 8 (Mahler)',
#  1008: 'Pagliacci',
#  1009: 'Symphony No. 41 (Mozart)',
#  1010: 'Porgy and Bess',
#  197619: 'The Alamo (2004 film)',
#  1012: 'The Threepenny Opera',
#  1013: "Bluebeard's Castle",
#  1014: 'Franz Schubert',
#  1015: 'Samuel Barber',
#  1016: 'Der Freischutz',
#  1017: 'Fidelio',
#  1018: 'The Planets',
#  1019: 'Jean Sibelius',
#  197628: 'James Joyce',
#  1021: 'Georges Bizet',
#  197630: 'Nitrogen',
#  1023: 'Edvard Grieg',
#  1024: 'Johann Sebastian Bach',
#  1025: 'Salome (opera)',
#  1026: 'Clarinet',
#  209531: 'The Godfather',
#  1028: 'Mass (music)',
#  1029: 'Carl Maria von Weber',
#  1030: 'Johannes Brahms',
#  1031: 'Pictures at an Exhibition',
#  1032: 'The Mikado',
#  1033: 'Vincenzo Bellini',
#  1034: 'Richard Strauss',
#  1035: 'Symphony No. 9 (Beethoven)',
#  1036: 'Sergei Rachmaninoff',
#  1037: 'The Four Seasons (Vivaldi)',
#  1038: 'Scott Joplin',
#  1039: 'Franz Schubert',
#  1041: 'The Makropulos Affair (opera)',
#  1042: 'Bachianas Brasileiras',
#  1043: 'Franz Xaver Sussmayr',
#  1044: 'Charles Mingus',
#  1045: 'Preludes (Chopin)',
#  1046: 'Bassoon',
#  1047: 'Aram Khachaturian',
#  197657: 'Stephen Crane',
#  1050: 'Spring Symphony',
#  1051: 'Fidelio',
#  1052: 'Academic Festival Overture',
#  1053: 'Arthur Sullivan',
#  1054: "L'Orfeo",
#  1055: 'Symphony No. 2 (Mahler)',
#  1056: 'Carmina Burana (Orff)',
#  197665: 'Convection',
#  1058: 'The Death of Klinghoffer',
#  1059: 'Heinrich Schutz',
#  1060: 'Sinfonia antartica',
#  1062: 'Turandot',
#  1063: 'Gustav Mahler',
#  1064: 'Antonin Dvorak',
#  ...}
