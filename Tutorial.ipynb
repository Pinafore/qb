# %%
from extract_features import *
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
questions = QuestionDatabase('data/questions.db')
guess_list = GuessList('data/guesses.db')

# %%
all_questions = questions.questions_with_pages()

# %%
from functional import seq
seq(all_questions.values()).map(len).sum()
# Out:
# 36448

# %%
q = all_questions['I Sing the Body Electric (poem)']
a = q[0]

# %%
all_questions.keys()
# Out:
# [u'I Sing the Body Electric (poem)',
#  u'A Good Man Is Hard to Find (short story)',
#  u'Chicago',
#  u'Dixie',
#  u'La Belle Dame sans Merci',
#  u'Ozymandias',
#  u'Rip Van Winkle',
#  u'Thanatopsis',
#  u'The Cask of Amontillado',
#  u'The Lottery',
#  u'The Love Song of J. Alfred Prufrock',
#  u'The Necklace',
#  u'The Rime of the Ancient Mariner',
#  u'The Significance of the Frontier in American History',
#  u'To His Coy Mistress',
#  u'Common sense',
#  u'Dizzy Gillespie',
#  u'Song of Myself',
#  u'Ulysses (novel)',
#  u'Sphere',
#  u'Virginia Woolf',
#  u'Noam Chomsky',
#  u'Virginia',
#  u'Benjamin Britten',
#  u'Nigeria',
#  u'Auguste Rodin',
#  u'Julius Caesar',
#  u'Graham Greene',
#  u'Felix Mendelssohn',
#  u'Hannah Arendt',
#  u'Rudyard Kipling',
#  u'Maurice Ravel',
#  u'Max Weber',
#  u'Bangladesh',
#  u'Zimbabwe',
#  u'Battle of Tannenberg',
#  u'Sigmund Freud',
#  u'Grover Cleveland',
#  u'Battle of Panipat (1761)',
#  u'Tennessee Williams',
#  u'Walt Whitman',
# ...
