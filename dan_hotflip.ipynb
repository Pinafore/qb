# %%
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F

from qanta.datasets.quiz_bowl import QuestionDatabase
from qanta.util.constants import GUESSER_TRAIN_FOLD, GUESSER_DEV_FOLD
from qanta.guesser.dan import DanGuesser, batchify
from qanta.guesser.nn import convert_text_to_embeddings_indices
from qanta.preprocess import tokenize_question

# %%
guesser = DanGuesser.load('output/guesser/qanta.guesser.dan.DanGuesser')
guesser.model = guesser.model.cuda()
criterion = nn.CrossEntropyLoss()

# %%
extracted_grads = {}

def extract_grad_hook(name):
    def hook(grad):
        extracted_grads[name] = grad
    return hook

def extract_grad_hook(name):
    def hook(grad):
        extracted_grads[name] = grad
    return hook

# %%
questions = QuestionDatabase().all_questions().values()
questions = [q for q in questions if q.fold == GUESSER_DEV_FOLD]

# %%
def prepare_batches(question_list):
    x_test = [convert_text_to_embeddings_indices(q, guesser.embedding_lookup)
            for q in question_list]
    
    for r in x_test:
        if len(r) == 0:
            r.append(guesser.embedding_lookup['UNK'])

    x_test = np.array(x_test)
    y_test = np.zeros(len(x_test))

    _, t_x_batches, t_len_batches, t_y_batches = batchify(
        guesser.batch_size, x_test, y_test, truncate=False, shuffle=False)
    
    return t_x_batches, t_len_batches

def guess(question_list, max_n_guesses):
    t_x_batches, t_len_batches = prepare_batches(question_list)
    guesses = []
    for b in range(len(t_x_batches)):
        t_x = Variable(t_x_batches[b])
        t_len = Variable(t_len_batches[b])
        
        guesser.model.eval()
        out = guesser.model(t_x, t_len, 0).data.cpu().numpy()
        for preds_scores in out:
            guesses.append([])
            preds = np.argsort(preds_scores)[:-10:-1]
            scores = preds_scores[preds]
            for p, s in zip(preds, scores):
                guesses[-1].append((guesser.i_to_class[p], s))
    return guesses

def get_onehot_grad(question_list):
    t_x_batches, t_len_batches = prepare_batches(question_list)
    grads = []
    for b in range(len(t_x_batches)):
        t_x = Variable(t_x_batches[b])
        t_len = Variable(t_len_batches[b])
        
        guesser.model.eval()
        out = guesser.model(t_x, t_len, 0, extract_grad_hook('embed'))
        scores, preds = torch.max(out, 1) # take gradient w.r.t top guess

        guesser.model.zero_grad()
        loss = criterion(out, preds)
        loss.backward()

        batch_size, length = t_x.size()
        embed = guesser.model.embeddings(t_x)
        embed_grad = extracted_grads['embed'].contiguous()
        onehot_grad = embed.view(-1) * embed_grad.view(-1)
        onehot_grad = onehot_grad.view(batch_size, length, -1).sum(-1)
        onehot_grad = onehot_grad.data.cpu().numpy()
        grads.append(onehot_grad)
    return np.concatenate(grads)

# %%
def greedy_remove(question_list):
    _xs = [tokenize_question(x.flatten_text()) for x in question_list]
    _ys = [x[0][0] for x in guess(_xs, 10)]

    xs, ys = list(_xs), list(_ys)

    removed_indices = [[] for _ in question_list]
    indices = [list(range(len(x))) for x in xs]
    alive = [True for _ in xs]

    while True:
        onehot_grad = get_onehot_grad(xs)
        for i, x in enumerate(xs):
            if len(x) == 1:
                alive[i] = False
            if alive[i]:
                drop_idx = np.argmax(onehot_grad[i][:len(x)])
                removed_indices[i].append(indices[i][drop_idx])
                indices[i] = indices[i][:drop_idx] + indices[i][drop_idx + 1:]
                x = x[:drop_idx] + x[drop_idx + 1:]
            xs[i] = x

        if sum(alive) == 0:
            break
                
        pred = [x[0][0] for x in guess(xs, 10)]
        for i, (x, y, z) in enumerate(zip(xs, ys, pred)):
            if z != y:
                alive[i] = False
                removed_indices[i] = removed_indices[i][:-1]
    return removed_indices

# %%
question_list = questions[:30]
removed_indices = greedy_remove(question_list)
xs = [tokenize_question(x.flatten_text()) for x in question_list]

# %%
for i in range(30):
    print('Original Question')
    print(' '.join(xs[i]))
    print()
    x_after = [w for j, w in enumerate(xs[i]) if j not in removed_indices[i]]
    print('Modified Question')
    print(' '.join(x_after))
    print()
    print('Original Guesses')
    for g, s in guess([xs[i]], 4)[0]:
        print(g, s)
    print()
    print('Modified Guesses')
    for g, s in guess([x_after], 4)[0]:
        print(g, s)
    print()
    print()
# Out:
# Original Question
# he rescues a hindu widow from ritual burning and takes her as his bride but first he must convince detective fix that he is not a bank robber this is after he has crossed three continents and two oceans on trains steamers and an elephant with his valet passepartout name this welltraveled jules verne character who circumnavigated the globe in 1920 hours
#
# Modified Question
# passepartout
#
# Original Guesses
# Around_the_World_in_Eighty_Days 5.0191
# Robinson_Crusoe 4.03111
# Phileas_Fogg 3.26174
# Ferdinand_Magellan 2.58749
# Sancho_Panza 2.37755
# Galahad 2.2981
# Captain_Nemo 2.28571
# Theseus 2.167
# Vishnu 2.14411
#
# Modified Guesses
# Around_the_World_in_Eighty_Days 26.0226
# Phileas_Fogg 22.0607
# International_Date_Line 19.9724
# William_Lyon_Mackenzie_King 10.9296
# Middlemarch 10.4852
# Abortion 10.2257
# Hypnos 9.58031
# A_Confederacy_of_Dunces 9.48001
# Lens 9.40255
#
#
# Original Question
# some scholars identify him with the two horned one mentioned in the koran he defeated darius iii at issus in 333 bc ten years before his own sudden death at age 33 name this macedonian king who founded a namesake city in northern egypt
#
# Modified Question
# macedonian
#
# Original Guesses
# Alexander_the_Great 7.65724
# Thebes,_Greece 2.7017
# Alexandria 2.44444
# Seth 2.10894
# Set_(deity) 2.03552
# Philip_II_of_Macedon 1.99891
# Sofoklis_Schortsanitis 1.93799
# Empedocles 1.93149
# Darius_III 1.9284
#
# Modified Guesses
# Alexander_the_Great 41.2911
# Stephen_Decatur 25.2745
# Alexandria 22.22
# Alexander_of_Macedon 21.3708
# Demosthenes 21.0444
# Elephant 19.7854
# Achaean_League 17.7796
# Bulgaria 16.6345
# Philip_II_of_Macedon 15.875
#
#
# Original Question
# they were not the punic wars but there were three of them and the second was the most famous it lasted seven years costing 2000 us dead and sixty million dollars and was the costliest war in the us between the war of 1812 and the mexican war name this war in which one side could use natural barriers such as the everglades to its advantage
#
# Modified Question
# were war
#
# Original Guesses
# War_of_1812 2.30857
# Paraguayan_War 2.29495
# Punic_Wars 1.95903
# Compromise_of_1850 1.9461
# Territories_of_the_United_States_on_stamps 1.92718
# Mexico 1.91063
# New_Jersey 1.87433
# Venice 1.83133
# Gulf_War 1.79321
#
# Modified Guesses
# War_of_1812 19.2485
# Spanish–American_War 17.0107
# Vietnam_War 16.0661
# Crimean_War 15.2523
# Franco-Prussian_War 14.1823
# War_of_the_Austrian_Succession 13.6087
# Peloponnesian_War 13.4881
# Territories_of_the_United_States_on_stamps 13.0711
# Gulf_War 12.6345
#
#
# Original Question
# before his medical internship in 1921 this man traveled to the soviet union to help fight a series of epidemics but was persuaded by lenin to use his business knowledge to help the country instead he then abandoned medicine helped start several businesses in the ussr and eventually bought the occidental petroleum corporation name this executive who helped spur greater eastwest ties
#
# Modified Question
# medical 1921 persuaded business he eventually corporation eastwest
#
# Original Guesses
# Theodore_Roosevelt 2.45174
# Armand_Hammer 2.43341
# Herbert_Hoover 2.36229
# Gutzon_Borglum 2.29219
# J._P._Morgan 2.28148
# Anton_Chekhov 2.15547
# Upton_Sinclair 2.1497
# Alfred_Thayer_Mahan 2.06274
# Eminent_domain 2.0574
#
# Modified Guesses
# Theodore_Roosevelt 14.7117
# J._P._Morgan 7.73772
# Franklin_D._Roosevelt 7.33573
# Charles_Evans_Hughes 7.13638
# William_Howard_Taft 6.20627
# Marcus_Garvey 6.18176
# Herbert_Hoover 6.12788
# Eminent_domain 5.87827
# Cornelius_Vanderbilt 5.86257
#
#
# Original Question
# iceland has many hot springs and volcanoes but thats not why its mean daily temperature is nine degrees higher than might be expected at that latitude what warmwater atlantic current moderates icelands climate
#
# Modified Question
# iceland has many hot springs and volcanoes but thats not why its mean daily temperature is nine degrees higher than might be expected at that latitude what warmwater atlantic current moderates icelands climate
#
# Original Guesses
# Gulf_Stream 10.4393
# Norway 5.0718
# Wind 3.9138
# William_Thomson,_1st_Baron_Kelvin 3.8821
# Mercury_(planet) 3.7132
# Sun 3.70066
# Mid-Atlantic_Ridge 3.59862
# RMS_Titanic 3.56811
# Venus 3.3262
#
# Modified Guesses
# Gulf_Stream 10.4393
# Norway 5.0718
# Wind 3.9138
# William_Thomson,_1st_Baron_Kelvin 3.8821
# Mercury_(planet) 3.7132
# Sun 3.70066
# Mid-Atlantic_Ridge 3.59862
# RMS_Titanic 3.56811
# Venus 3.3262
#
#
# Original Question
# of the nine defendants only matthew killroy and hugh montgomery were found guilty and then only of manslaughter they were granted benefit of clergy because both could read and were branded on the thumb as punishment of what december 1770 crime were these soldiers accused which resulted in the deaths of five men including crispus attucks
#
# Modified Question
# hugh manslaughter benefit because on 1770 soldiers which deaths men including attucks
#
# Original Guesses
# Boston_Massacre 7.4551
# Boston 3.77168
# Salem_witch_trials 3.13644
# Nuremberg_trials 3.04278
# Haymarket_affair 2.79375
# Trial_of_Socrates 2.54321
# John_Brown_(abolitionist) 2.50705
# Bill_of_attainder 2.44459
# Fugitive_slave_laws 2.11626
#
# Modified Guesses
# Boston_Massacre 22.8249
# Indian_Rebellion_of_1857 6.83787
# John_Singleton_Copley 6.61108
# Boston 6.50938
# Triangle_Shirtwaist_Factory_fire 6.18441
# Nuremberg_trials 5.71944
# Battle_of_Bunker_Hill 5.36715
# Henry_Fielding 5.19016
# Crispus_Attucks 5.17992
#
#
# Original Question
# named for the teutonic goddess of the dawn it was set in 325 ad by the council of nicaea as being the first sunday after the first full moon after the vernal equinox name this holiday further restricted as occurring between march 22 and april 25
#
# Modified Question
# named for goddess of by council of nicaea as being first sunday after first full moon after the vernal equinox holiday as between and
#
# Original Guesses
# Easter 5.91602
# Pentecost 3.56995
# Titan 3.19721
# Zoroastrianism 3.17196
# Advent 3.10269
# First_Council_of_Nicaea 2.653
# Battle_of_the_Bulge 2.62081
# Teotihuacan 2.61624
# Christmas 2.55314
#
# Modified Guesses
# Easter 11.7796
# Virgil_Thomson 5.93436
# Pentecost 5.75461
# Paradiso 5.02317
# Spring_(season) 4.86632
# Sukkot 4.74561
# Advent 4.52344
# Transubstantiation 4.29763
# Epiphany 4.25093
#
#
# Original Question
# he died in 1542 at the age of 42 earlier he had been with pizarro in peru and was named governor of cuba in 1539 he set out to conquer florida and explored much of the american south name this spanish explorer who saw the mississippi river and was buried in it
#
# Modified Question
# 1542 of been with peru named of cuba 1539 to conquer of spanish who mississippi river and buried
#
# Original Guesses
# Hernando_de_Soto 11.5691
# Zebulon_Pike 4.38046
# Vasco_Núñez_de_Balboa 4.20497
# Juan_Ponce_de_León 4.1203
# Amerigo_Vespucci 3.94481
# Francisco_Pizarro 3.30349
# Jacques_Marquette 3.17262
# Jacques_Cartier 3.14164
# Hernán_Cortés 3.03842
#
# Modified Guesses
# Hernando_de_Soto 23.087
# Hernán_Cortés 8.02464
# Francisco_Pizarro 7.61235
# Vasco_Núñez_de_Balboa 7.49014
# Zebulon_Pike 7.32531
# Jacques_Cartier 7.01207
# Jacques_Marquette 6.84038
# Mississippi 6.82376
# Juan_Ponce_de_León 6.55227
#
#
# Original Question
# in 1859 lescarbault discovered a black dot in rapid transit across the solar disk urbain leverrier showed that it would explain the anomalous perihelion advance of mercury unfortunately it was never seen again and the observations of mercury were later explained by general relativity name this onetime tenth member of the solar system which lent its name to the home of star treks mr spock
#
# Modified Question
# would which treks
#
# Original Guesses
# Vulcan 6.97543
# Mercury_(planet) 3.54864
# Neptune 3.40404
# Precession 3.27055
# Michelson–Morley_experiment 3.15756
# Uranus 2.53642
# Halley's_Comet 2.48821
# Venus 2.05301
# Sunspot 2.02381
#
# Modified Guesses
# Vulcan 22.6443
# Bataan_Death_March 9.3295
# Appian_Way 8.09809
# Mithraism 7.81375
# Gilgamesh 7.21723
# Triumph 7.17142
# Talc 7.15705
# Thomas_Becket 6.96954
# Apennine_Mountains 6.92524
#
#
# Original Question
# on october 17 1978 president jimmy carter signed a bill restoring us citizenship to this man a mississippi senator from 1847 to 1851 and 1857 to 1861 name this secretary of war under franklin pierce and from 1861 to 1865 president of the confederacy
#
# Modified Question
# on president us to man mississippi from to and to 1861 of war under franklin pierce and from 1861 to 1865 president of confederacy
#
# Original Guesses
# Jefferson_Davis 7.98676
# James_Buchanan 4.54914
# Abraham_Lincoln 4.03232
# John_C._Breckinridge 3.66213
# Judah_P._Benjamin 3.52896
# Lewis_Cass 3.45168
# Ulysses_S._Grant 3.28626
# Millard_Fillmore 3.12588
# Quartz 2.93558
#
# Modified Guesses
# Jefferson_Davis 18.0506
# John_C._Breckinridge 8.12254
# Judah_P._Benjamin 8.05801
# Alexander_H._Stephens 7.68386
# James_Buchanan 7.25496
# Albert_Sidney_Johnston 7.25223
# Abraham_Lincoln 7.08837
# Robert_E._Lee 6.58111
# Sam_Houston 5.82453
#
#
# Original Question
# lured to london in 1774 by benjamin west he stayed until his death 41 years later nevertheless he is considered a very american painter with portraits of samuel adams john hancock and john adams to his credit name this bostonborn artist who also did portraits of lord cornwallis as well as the death of lord chatham and the victory of lord duncan
#
# Modified Question
# by later american painter to who death chatham
#
# Original Guesses
# John_Singleton_Copley 4.62852
# Thomas_Gainsborough 3.83359
# George_Washington 3.56589
# J._M._W._Turner 3.13364
# Alexander_Hamilton 3.05298
# John_Trumbull 2.99936
# Benjamin_West 2.90089
# John_Adams 2.74185
# Joshua_Reynolds 2.65377
#
# Modified Guesses
# John_Singleton_Copley 17.226
# John_Brown_(abolitionist) 8.70231
# Winslow_Homer 8.37013
# Watson_and_the_Shark 8.02581
# Benjamin_West 7.24859
# William_Pitt,_1st_Earl_of_Chatham 6.99455
# The_Death_of_General_Wolfe 6.78989
# Thomas_Gainsborough 6.46826
# J._M._W._Turner 6.252
#
#
# Original Question
# named from proverbs 1129 a 1995 revival at the national actors theater starred charles durning as matthew harrison brady and as george c scott as henry drummond inwhat 1955 play by jerome lawrence and robert edwin lee modeled on the 1925 scopes trial
#
# Modified Question
# named 1129 a the theater as matthew harrison brady and as as henry drummond play by jerome lawrence and robert edwin lee on the trial
#
# Original Guesses
# Inherit_the_Wind 9.8289
# Daniel_Webster 3.61443
# Boston 3.00835
# New_England_Patriots 2.46638
# The_Turn_of_the_Screw 2.44755
# Albert_Einstein 2.13231
# Elmer_Rice 2.12957
# Great_Awakening 2.10994
# Sacco_and_Vanzetti 2.09453
#
# Modified Guesses
# Inherit_the_Wind 17.8232
# Daniel_Webster 4.94037
# Rosencrantz_and_Guildenstern_Are_Dead 4.23369
# Boston_Massacre 4.16276
# Ecuador 4.08808
# The_Turn_of_the_Screw 4.02385
# Second_Bank_of_the_United_States 4.02286
# Magnetic_field 3.94596
# Boston 3.69764
#
#
# Original Question
# the title character and friends seize the acropolis to cut off the athenian treasury the seizure is part of a plot by the greek women to end the peloponnesian war by refusing to have intercourse with their husbands until a treaty is signed inwhich comedy by aristophanes
#
# Modified Question
# title character and acropolis to cut part the women to end the war to intercourse their husbands until comedy by aristophanes
#
# Original Guesses
# Lysistrata 9.13764
# Aristophanes 4.95583
# Pericles 4.30463
# Cyprus 2.9295
# Volpone 2.83
# A_Midsummer_Night's_Dream 2.82525
# Trial_of_Socrates 2.79686
# The_Birds_(play) 2.77761
# Athens 2.77628
#
# Modified Guesses
# Lysistrata 15.8035
# Yukio_Mishima 5.36225
# Aristophanes 5.25592
# The_Canterbury_Tales 5.126
# The_Clouds 4.86438
# The_Wife_of_Bath's_Tale 4.85242
# The_Tale_of_Genji 4.71959
# Parthenon 4.58038
# The_Two_Noble_Kinsmen 4.44267
#
#
# Original Question
# according to the oxford english dictionary the words fancyfree eventful dislocate premeditated lackluster barefaced dwindle submerged and assassination all debuted in print in the works of what member of lord chamberlains men and the blackfriars theater born in stratfordonavon
#
# Modified Question
# according to the oxford english dictionary the words fancyfree eventful dislocate premeditated lackluster barefaced dwindle submerged and assassination all debuted in print in the works of what member of lord chamberlains men and the blackfriars theater born in stratfordonavon
#
# Original Guesses
# Christopher_Marlowe 3.53752
# William_Shakespeare 3.20128
# Globe_Theatre 3.12707
# Benjamin_Franklin 2.86371
# Refractive_index 2.77528
# River_Thames 2.74386
# Aaron_Copland 2.50367
# J._R._R._Tolkien 2.43174
# Myanmar 2.28117
#
# Modified Guesses
# Christopher_Marlowe 3.53752
# William_Shakespeare 3.20128
# Globe_Theatre 3.12707
# Benjamin_Franklin 2.86371
# Refractive_index 2.77528
# River_Thames 2.74386
# Aaron_Copland 2.50367
# J._R._R._Tolkien 2.43174
# Myanmar 2.28117
#
#
# Original Question
# it was followed by a wind in the door and a swiftly tilting planet this 1962 novel introduces the murry children who engage in a cosmic battle against it a great evil brain that despises individuality name this newbery award winner by madeleine lengle
#
# Modified Question
# murry
#
# Original Guesses
# A_Wrinkle_in_Time 5.36498
# William_Golding 2.09538
# Saul_Bellow 2.02239
# Salman_Rushdie 1.73295
# Brave_New_World 1.68193
# Milky_Way 1.66492
# Zoroastrianism 1.65742
# Entropy 1.58671
# Flower_of_Evil 1.50491
#
# Modified Guesses
# A_Wrinkle_in_Time 26.4472
# Hawaii 14.7593
# Lines_written_a_few_miles_above_Tintern_Abbey 11.3354
# Fruit_fly 10.6995
# Gaza_Strip 10.2923
# Trout_Quintet 10.2303
# Judaism 9.9756
# Gregor_Mendel 9.81996
# Duino_Elegies 9.81268
#
#
# Original Question
# his 1941 short story nightfall is considered by many to be the finest sciencefiction story ever written he was born in russia in 1920 but was brought to the us at the age of three name this biochemist who also wrote the foundation series of novels
#
# Modified Question
# foundation
#
# Original Guesses
# Isaac_Asimov 6.83828
# Saki 4.45946
# Kilgore_Trout 3.78739
# Kazuo_Ishiguro 3.3414
# Zane_Grey 3.04039
# Kenzaburō_Ōe 2.80103
# Ralph_Ellison 2.69182
# H._G._Wells 2.5039
# Saul_Bellow 2.47287
#
# Modified Guesses
# Isaac_Asimov 41.0583
# Milton_Friedman 30.8429
# Vietnam_Veterans_Memorial 29.6361
# Hosni_Mubarak 27.9198
# Dag_Hammarskjöld 24.8237
# Poliomyelitis 23.0932
# Neutrino 21.1085
# Isaac_Stern 20.9521
# Abe_Fortas 20.0762
#
#
# Original Question
# a student of anthropologist bronislaw malinowski he analyzed his own kikuyu culture in 1938s facing mount kenya imprisoned by the british for involvement in the mau mau uprising he was released in 1961 name this first prime minister and president of kenya
#
# Modified Question
# a of bronislaw malinowski he his in 1938s mount kenya imprisoned by the for involvement in the mau mau he released in first minister and president of kenya
#
# Original Guesses
# Jomo_Kenyatta 10.1291
# Bronisław_Malinowski 5.95561
# Mau_Mau_Uprising 5.27043
# Idi_Amin 4.54726
# Kenya 4.09634
# Wole_Soyinka 3.92224
# Winston_Churchill 3.89961
# Facing_Mount_Kenya 3.68859
# W._E._B._Du_Bois 3.66648
#
# Modified Guesses
# Jomo_Kenyatta 15.9015
# Idi_Amin 6.46234
# Winston_Churchill 6.32463
# A_Grain_of_Wheat 5.49011
# Wole_Soyinka 5.32549
# Mau_Mau_Uprising 5.16226
# Vitamin_C 4.84534
# Petals_of_Blood 4.63671
# Julius_Nyerere 4.43209
#
#
# Original Question
# it was adapted to languages such as hattis and hurrian in asia minor elbaite in syria and urartian in armenia the babylonian and assyrian versions each used 300 to 600 arbitrary symbols ofwhat method of writing whose name is latin for wedgeshaped
#
# Modified Question
# it was to as and hurrian in elbaite in syria and urartian in the babylonian and assyrian each used 300 to symbols of writing whose latin for wedgeshaped
#
# Original Guesses
# Cuneiform_script 6.8007
# Aramaic_language 3.9652
# Linear_B 3.32211
# Turkey 2.86433
# Stress_(mechanics) 2.84848
# Hebrew_language 2.79685
# Abacus 2.75543
# Lebanon 2.58242
# Caucasus_Mountains 2.51668
#
# Modified Guesses
# Cuneiform_script 12.3648
# Aramaic_language 5.9535
# Nineveh 5.6475
# Abacus 5.13359
# Linear_B 4.64155
# Neo-Assyrian_Empire 4.52873
# E_pluribus_unum 4.51535
# Lebanon 4.45382
# Troubadour 4.32107
#
#
# Original Question
# unlike the canadian provinces of newfoundland prince edward island and nova scotia none of which border any us state what province borders the most states new york vermont new hampshire and maine
#
# Modified Question
# unlike the canadian provinces of newfoundland prince edward island and nova scotia none of which border any us state what province borders the most states new york vermont new hampshire and maine
#
# Original Guesses
# Maine 6.96171
# New_Hampshire 6.49291
# New_Brunswick 5.66232
# Labrador 4.74425
# Massachusetts 4.69414
# British_Columbia 3.70763
# Aroostook_War 3.69102
# Prince_Edward_Island 3.67137
# New_Jersey 3.57765
#
# Modified Guesses
# Maine 6.96171
# New_Hampshire 6.49291
# New_Brunswick 5.66232
# Labrador 4.74425
# Massachusetts 4.69414
# British_Columbia 3.70763
# Aroostook_War 3.69102
# Prince_Edward_Island 3.67137
# New_Jersey 3.57765
#
#
# Original Question
# his collected works fill 143 volumes and include entoptic colors on the theory of colors and the metamorphosis of plants name this german poet and playwright of gotz von berlichingen clavigo iphegenia in tauris and faust
#
# Modified Question
# his works 143 volumes and include entoptic colors on the theory of colors and the metamorphosis of plants german poet and playwright of gotz von berlichingen clavigo iphegenia in tauris and faust
#
# Original Guesses
# Johann_Wolfgang_von_Goethe 14.0156
# William_Shakespeare 3.776
# Germany 3.69594
# Thomas_Mann 3.30396
# Tree 2.85768
# Archibald_MacLeish 2.70059
# Schubert_Thematic_Catalogue 2.53579
# Flower 2.49857
# Ovid 2.46079
#
# Modified Guesses
# Johann_Wolfgang_von_Goethe 17.0932
# William_Shakespeare 4.67302
# Germany 4.51028
# Thomas_Mann 4.35532
# Tree 3.53369
# German_language 3.26863
# Archibald_MacLeish 3.171
# Flower 3.12959
# Ovid 3.0509
#
#
# Original Question
# new york federal district court judge john woolsey ruled although it contains many words usually considered dirty i have not found anything that i consider to be dirt for dirts sake name this 1922 novel featuring a jewish advertising canvasser and which focuses on the events of one day written by james joyce
#
# Modified Question
# york court judge woolsey although words have consider to for 1922 novel which on one day joyce
#
# Original Guesses
# Ulysses_(novel) 6.21187
# Marc_Chagall 3.0457
# The_Crucible 2.2388
# Death_of_a_Salesman 2.14662
# Nighthawks 2.03471
# Tom_Stoppard 1.99829
# Poland 1.74604
# Sylvia_Plath 1.73453
# Karma 1.72444
#
# Modified Guesses
# Ulysses_(novel) 20.8699
# Finnegans_Wake 6.71746
# Gideon 6.34709
# Nighthawks 5.40759
# Sister_Carrie 5.12291
# Tree 4.99581
# Éamon_de_Valera 4.98108
# Marc_Chagall 4.6637
# J._D._Salinger 4.63881
#
#
# Original Question
# caused by the spirochete borrelia burgdorferi if caught early it can be treated with tetracycline if not treated the characteristic rash is followed by periodic arthritis and possibly meningitis name this disease carried by some species of deer tick
#
# Modified Question
# caused by the borrelia burgdorferi if early can be treated with if not treated the characteristic rash followed by arthritis and possibly meningitis disease by some of deer tick
#
# Original Guesses
# Lyme_disease 12.4911
# Syphilis 4.48661
# Malaria 3.45534
# Huntington's_disease 2.95676
# Precession 2.87862
# Cholera 2.81971
# Joseph_Haydn 2.782
# Leprosy 2.72935
# Addison's_disease 2.67833
#
# Modified Guesses
# Lyme_disease 19.5167
# Tuberculosis 5.66405
# Syphilis 5.37333
# Malaria 4.90212
# Addison's_disease 4.39236
# Deer 4.32951
# Parkinson's_disease 4.25862
# Leprosy 4.23821
# Pierre-Auguste_Renoir 3.88192
#
#
# Original Question
# art aficionados carlo starnazzi and claudio santori announced in late 1995 that its background is the village of ponte a buriano on the river arno near the tuscan city of arezzo name this da vinci painting commissioned for francesco del giocondo that features arts most famous enigmatic smile
#
# Modified Question
# enigmatic
#
# Original Guesses
# Mona_Lisa 6.77641
# Florence 5.16759
# Leonardo_da_Vinci 3.98942
# Apennine_Mountains 3.49157
# Venice 3.30066
# Sicily 3.16139
# Italy 3.09089
# House_of_Sforza 3.0814
# Arno 2.9155
#
# Modified Guesses
# Mona_Lisa 23.4806
# Leonardo_da_Vinci 19.037
# William_Randolph_Hearst 13.6112
# Madonna_of_the_Harpies 13.493
# Amazon_River 13.2702
# The_Gold-Bug 13.2557
# Angel_Falls 13.1881
# Ayn_Rand 12.8622
# Cambrian 12.7612
#
#
# Original Question
# composed of the harivamsa and 18 parvans or chapters it is ascribed to the sage vyasa and it is a valuable source on the transition from vedic to hindu india name this epic which tells of a dynastic war between the pandavas and kauravas and features the god krishna
#
# Modified Question
# of the harivamsa 18 parvans to the sage a on the from to hindu epic which tells of a the kauravas and the
#
# Original Guesses
# Mahabharata 8.823
# Bhagavad_Gita 4.62914
# India 4.51965
# Punjab_(region) 3.19404
# Ramayana 3.18545
# Sanskrit 3.0567
# Rigveda 2.889
# Rama 2.82524
# Arjuna 2.77908
#
# Modified Guesses
# Mahabharata 16.9256
# Krishna 7.09349
# Abhijñānaśākuntalam 6.66023
# Punjab_(region) 6.13183
# Upanishads 5.76713
# Rama 5.13478
# Ramayana 4.87217
# Kālidāsa 4.86956
# India 4.77047
#
#
# Original Question
# the subject of the 1994 oscarwinning feature documentary a strong clear vision she was commissioned to sculpt an alabama monument commemorating the civil rights movement name this yale alum best known for designing the vietnam veterans memorial
#
# Modified Question
# the subject of the 1994 oscarwinning feature documentary a strong vision was commissioned to sculpt an alabama monument commemorating the civil rights name this alum best known for designing the vietnam veterans memorial
#
# Original Guesses
# Gutzon_Borglum 4.26791
# Maya_Lin 4.12899
# Vietnam_Veterans_Memorial 3.0868
# Augustus_Saint-Gaudens 3.00296
# Mount_Rushmore 2.99767
# Rosie_the_Riveter/World_War_II_Home_Front_National_Historical_Park 2.79236
# Hector_Berlioz 2.65608
# Dwight_D._Eisenhower 2.53257
# Aaron_Copland 2.39252
#
# Modified Guesses
# Gutzon_Borglum 5.92389
# Maya_Lin 4.67707
# Augustus_Saint-Gaudens 4.15618
# Vietnam_Veterans_Memorial 3.75687
# Mount_Rushmore 3.655
# Rosie_the_Riveter/World_War_II_Home_Front_National_Historical_Park 2.89331
# Nelson_Mandela 2.67327
# Agent_Orange 2.64522
# Aaron_Copland 2.61523
#
#
# Original Question
# massachusetts residents love the trailing arbutus their state flower however this species has another common name which is more readily associated with the first european inhabitants of the area give the other common name of the massachusetts state flower shared with the ship which brought the region its most famous immigrants
#
# Modified Question
# trailing arbutus which with give other common of massachusetts state flower shared with ship which brought its
#
# Original Guesses
# Mayflower 5.86369
# Massachusetts 3.99387
# Maine 3.76548
# New_Hampshire 3.42599
# Philip_Freneau 3.4031
# When_Lilacs_Last_in_the_Dooryard_Bloom'd 3.00774
# Rose 2.95828
# Lotus_Software 2.61884
# Crane 2.60351
#
# Modified Guesses
# Mayflower 16.2015
# Philip_Freneau 7.90239
# When_Lilacs_Last_in_the_Dooryard_Bloom'd 7.53706
# The_Raft_of_the_Medusa 5.91203
# Argo 5.65796
# Scylla 5.37956
# Massachusetts 5.36591
# Adams 5.17845
# Rhode_Island 5.06422
#
#
# Original Question
# its twice as strong under compression than concrete and a 10squarecentimeter column can support an 11000 pound elephant though it burns too readily to be widely used in construction it lacks the weak spots of conventional wood and is associated with structures in the tropics name this woody plant whose shoots are commonly found in stirfry dishes
#
# Modified Question
# as concrete pound though readily spots wood tropics plant in dishes
#
# Original Guesses
# Banana 3.38287
# Tree 2.51108
# The_Waste_Land 2.36601
# Lithium 1.88584
# Brazil 1.87595
# Potato 1.85768
# Asbestos 1.79537
# Swan 1.7066
# Fallingwater 1.59645
#
# Modified Guesses
# Banana 16.697
# Chaparral 8.89616
# William_Howard_Taft 6.90052
# Christopher_Marlowe 6.57228
# Brazil 6.51219
# Roald_Dahl 6.36168
# Coffee 6.3232
# Walt_Whitman 6.17033
# Green_Eggs_and_Ham 6.05209
#
#
# Original Question
# the pretext for this war was the protection of christian pilgrims in the holy land but the real issue concerned russias attempt to control the straits of constantinople name this war fought near the shores of the black sea which lasted from 1853 to 1856 and which witnessed the famous charge of the light brigade
#
# Modified Question
# pretext war holy but straits war near black which 1856 which charge brigade
#
# Original Guesses
# Crimean_War 9.36945
# Treaty_of_Brest-Litovsk 2.9792
# Gallipoli_Campaign 2.94518
# First_Crusade 2.77528
# Gallipoli 2.2998
# War_of_the_Austrian_Succession 2.29269
# Ottoman_Empire 2.25418
# Spanish–American_War 2.12749
# Russo-Japanese_War 2.03824
#
# Modified Guesses
# Crimean_War 24.027
# Franco-Prussian_War 8.10743
# Spanish–American_War 7.41421
# Yom_Kippur_War 6.83358
# Jihad 6.79583
# Armenia–United_States_relations 6.57494
# Stephen_Crane 6.39381
# Wars_of_the_Roses 6.35935
# Russo-Japanese_War 6.35899
#
#
# Original Question
# the son of princess dechtire and the god lug loo in the cattle raid of cooley he singlehandedly staves off an invading force from connaught name this chief servant of king conor a key character in the irish ulster cycle
#
# Modified Question
# the son of dechtire and the in the cattle raid of cooley he singlehandedly off an from chief of king conor a character in the irish ulster cycle
#
# Original Guesses
# Cú_Chulainn 4.45724
# Thor 2.6876
# Fionn_mac_Cumhaill 2.00926
# Eugène_Ionesco 1.88277
# Zeus 1.84024
# Enthalpy 1.83667
# Perseus 1.81583
# Indra 1.80245
# James_Prescott_Joule 1.78728
#
# Modified Guesses
# Cú_Chulainn 11.7828
# Fionn_mac_Cumhaill 5.2201
# Odin 3.54919
# Willie_Stark 3.2721
# James_Prescott_Joule 3.12415
# Éamon_de_Valera 3.12252
# Deirdre_of_the_Sorrows 3.03321
# Eugène_Ionesco 2.69519
# Indra 2.66338
#
#
# Original Question
# the boettcher memorial conservatory the gates planetarium loretto heights college and the former lowry air force base are all foundin what city formed at the junction of cherry creek and the south platte river the most populous in colorado
#
# Modified Question
# the boettcher memorial the gates and the former lowry air base are all city formed at the junction of cherry creek and the south platte river the most populous in colorado
#
# Original Guesses
# Denver 6.04081
# Hull_House 3.27231
# Colorado 2.96806
# Wichita 2.58167
# Chile 2.54062
# Boston 2.51166
# Hydrogen_bond 2.39111
# Base_(chemistry) 2.37061
# Austin,_Texas 2.3527
#
# Modified Guesses
# Denver 10.1757
# Colorado 5.16616
# Paraguay 3.77697
# Wichita 3.73297
# Arkansas_River 3.67579
# Omaha,_Nebraska 3.4596
# Auguste_Rodin 3.3196
# Atlanta 3.21774
# Patagonia 3.13585
