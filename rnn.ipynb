# %%
import os
import os
import sys
import random
import numpy as np
import argparse
import chainer
import pickle
from typing import List, Dict, Tuple, Optional

from qanta import logging
from qanta.config import conf
from qanta.guesser.abstract import AbstractGuesser

from qanta.buzzer import configs
from qanta.buzzer.progress import ProgressBar
from qanta.buzzer.trainer import Trainer
from qanta.buzzer.iterator import QuestionIterator
from qanta.buzzer.util import load_quizbowl, GUESSERS
from qanta.buzzer.models import MLP, RNN
from qanta.buzzer import constants as bc
from qanta.util import constants as c


log = logging.get(__name__)

N_GUESSERS = len(GUESSERS)
N_GUESSES = conf['buzzer']['n_guesses']

# %%
def dense_vector(dicts: List[List[Dict[str, float]]],
        wordvecs: List[List[np.ndarray]], step_size=1) -> List[List[float]]:

    length = len(dicts)
    prev_vec = [0.02 for _ in range(N_GUESSERS * N_GUESSES)]
    vecs = []
    for i in range(length):
        if len(dicts[i]) != N_GUESSERS:
            raise ValueError("Inconsistent number of guessers ({0}, {1}).".format(
                N_GUESSERS, len(dicts)))
        vec = []
        diff_vec = []
        isnew_vec = []
        for j in range(N_GUESSERS):
            dic = sorted(dicts[i][j].items(), key=lambda x: x[1], reverse=True)
            for guess, score in dic:
                vec.append(score)
                if i > 0 and guess in dicts[i-1][j]:
                    diff_vec.append(score - dicts[i-1][j][guess])
                    isnew_vec.append(0)
                else:
                    diff_vec.append(score) 
                    isnew_vec.append(1)
            if len(dic) < N_GUESSES:
                for k in range(max(N_GUESSES - len(dic), 0)):
                    vec.append(0)
                    diff_vec.append(0)
                    isnew_vec.append(0)
        features = [vec[0], vec[1], vec[2],
                    np.average(vec[:10]), np.average(prev_vec[:10]),
                    np.var(vec[:10]), np.var(prev_vec[:10]),
                    sum(isnew_vec[:10]),
                    isnew_vec[0], isnew_vec[1], isnew_vec[2],
                    diff_vec[0], diff_vec[1]
                    vec[0] - vec[1], vec[1] - vec[2], 
                    vec[0] / vec[1], vec[0] / prev_vec[0],
                    vec[0] - prev_vec[0], vec[1] - prev_vec[1]
                    ]

        vecs.append(features)
        prev_vec = vec
    return vecs

option2id, all_guesses = load_quizbowl()
iterators = dict()
for fold in c.BUZZER_INPUT_FOLDS:
    iterators[fold] = QuestionIterator(all_guesses[fold], option2id,
        batch_size=128, make_vector=dense_vector)
# Out:
# 2017-05-26 02:06:19,269 - qanta.buzzer.util - INFO - Merging guesser DataFrames.
# 2017-05-26 02:06:19,271 - qanta.buzzer.util - INFO - Merged buzzertrain exists, skipping.
# 2017-05-26 02:06:19,272 - qanta.buzzer.util - INFO - Merged buzzerdev exists, skipping.
# 2017-05-26 02:06:19,273 - qanta.buzzer.util - INFO - Merged dev exists, skipping.
# 2017-05-26 02:06:19,274 - qanta.buzzer.util - INFO - Merged test exists, skipping.
# 2017-05-26 02:06:19,274 - qanta.buzzer.util - INFO - Merged expo exists, skipping.
# 2017-05-26 02:06:19,275 - qanta.buzzer.util - INFO - Loading data
# 2017-05-26 02:06:19,276 - qanta.datasets.quiz_bowl - WARNING - Using QuizBowlDataset with guesser and buzzer training data, make sure you know what you are doing!
# 2017-05-26 02:06:26,631 - qanta.buzzer.util - INFO - Number of options 8247
# 2017-05-26 02:06:46,684 - qanta.buzzer.util - INFO - Loading buzzertrain guesses
# 2017-05-26 02:06:49,779 - qanta.buzzer.util - INFO - Loading buzzerdev guesses
# 2017-05-26 02:06:50,894 - qanta.buzzer.util - INFO - Loading dev guesses
# 2017-05-26 02:06:51,484 - qanta.buzzer.util - INFO - Loading test guesses
# 2017-05-26 02:06:51,506 - qanta.buzzer.util - INFO - Loading expo guesses
# 2017-05-26 02:06:53,502 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 23210/23211
# 2017-05-26 02:11:04,449 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:11:04,450 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 7586/7587
# 2017-05-26 02:12:22,338 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:12:22,339 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 2088/2089
# 2017-05-26 02:12:48,587 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:12:48,588 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 1411/1412
# 2017-05-26 02:13:03,664 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:13:03,665 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 68/69
# 2017-05-26 02:13:04,103 - qanta.buzzer.iterator - INFO - Finish creating batches

# %%
n_hidden = 10
cfg = configs.rnn()
cfg.n_hidden = n_hidden
cfg.model_name = 'rnn_{}'.n_hidden
cfg.model_dir = 'output/buzzer/{}.'

model = RNN(iterators[c.BUZZER_TRAIN_FOLD].n_input, cfg.n_hidden, N_GUESSERS + 1)
chainer.cuda.get_device(0).use()
model.to_gpu(0)

trainer = Trainer(model, cfg.model_dir)
trainer.run(iterators[c.BUZZER_TRAIN_FOLD], iterators[c.BUZZER_DEV_FOLD], 25)

for fold in c.BUZZER_GENERATION_FOLDS:
    test_iter = iterators[fold]
    buzzes = trainer.test(test_iter)
    log.info('{0} buzzes generated. Size {1}.'.format(fold, len(buzzes)))
    buzzes_dir = bc.BUZZES_DIR.format(fold, cfg.model_name)
    with open(buzzes_dir, 'wb') as outfile:
        pickle.dump(buzzes, outfile)
    log.info('Buzzes saved to {0}.'.format(buzzes_dir))
# Out:
# 2017-05-26 02:16:34,614 - qanta.buzzer.trainer - INFO - epoch 0
# 2017-05-26 02:17:18,884 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.66
# 2017-05-26 02:17:24,167 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.70
# 2017-05-26 02:17:24,174 - qanta.buzzer.trainer - INFO - epoch 1
# 2017-05-26 02:18:01,677 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.69
# 2017-05-26 02:18:08,823 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.75
# 2017-05-26 02:18:08,902 - qanta.buzzer.trainer - INFO - epoch 2
# 2017-05-26 02:18:35,771 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.74
# 2017-05-26 02:18:40,922 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.79
# 2017-05-26 02:18:40,927 - qanta.buzzer.trainer - INFO - epoch 3
# 2017-05-26 02:19:12,475 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.79
# 2017-05-26 02:19:17,632 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.80
# 2017-05-26 02:19:17,637 - qanta.buzzer.trainer - INFO - epoch 4
# 2017-05-26 02:19:44,300 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.80
# 2017-05-26 02:19:55,772 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.81
# 2017-05-26 02:19:55,780 - qanta.buzzer.trainer - INFO - epoch 5
# 2017-05-26 02:20:27,437 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.82
# 2017-05-26 02:20:32,627 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.79
# 2017-05-26 02:20:32,632 - qanta.buzzer.trainer - INFO - epoch 6
# 2017-05-26 02:21:06,062 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.82
# 2017-05-26 02:21:16,256 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.79
# 2017-05-26 02:21:16,261 - qanta.buzzer.trainer - INFO - epoch 7
# 2017-05-26 02:21:55,433 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.82
# 2017-05-26 02:22:00,857 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.82
# 2017-05-26 02:22:00,862 - qanta.buzzer.trainer - INFO - epoch 8
# 2017-05-26 02:22:31,814 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 02:22:39,700 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.82
# 2017-05-26 02:22:39,705 - qanta.buzzer.trainer - INFO - epoch 9
# 2017-05-26 02:23:17,988 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 02:23:25,782 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.83
# 2017-05-26 02:23:25,787 - qanta.buzzer.trainer - INFO - epoch 10
# 2017-05-26 02:23:53,762 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 02:24:06,646 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.83
# 2017-05-26 02:24:06,652 - qanta.buzzer.trainer - INFO - epoch 11
# 2017-05-26 02:24:47,047 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:24:54,326 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.82
# 2017-05-26 02:24:54,334 - qanta.buzzer.trainer - INFO - epoch 12
# 2017-05-26 02:25:33,105 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:25:42,910 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 02:25:42,916 - qanta.buzzer.trainer - INFO - epoch 13
# 2017-05-26 02:26:25,520 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:26:30,688 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 02:26:30,694 - qanta.buzzer.trainer - INFO - epoch 14
# 2017-05-26 02:26:56,603 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:27:01,743 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 02:27:01,748 - qanta.buzzer.trainer - INFO - epoch 15
# 2017-05-26 02:27:30,632 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:27:35,796 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 02:27:35,801 - qanta.buzzer.trainer - INFO - epoch 16
# 2017-05-26 02:28:13,303 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:28:18,909 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 02:28:18,914 - qanta.buzzer.trainer - INFO - epoch 17
# 2017-05-26 02:28:44,115 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:28:51,333 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 02:28:51,338 - qanta.buzzer.trainer - INFO - epoch 18
# 2017-05-26 02:29:16,692 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:29:21,973 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.83
# 2017-05-26 02:29:21,980 - qanta.buzzer.trainer - INFO - epoch 19
# 2017-05-26 02:29:51,203 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:29:56,428 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 02:29:56,433 - qanta.buzzer.trainer - INFO - epoch 20
# 2017-05-26 02:30:23,383 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:30:28,608 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 02:30:28,613 - qanta.buzzer.trainer - INFO - epoch 21
# 2017-05-26 02:30:57,476 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:31:02,700 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 02:31:02,705 - qanta.buzzer.trainer - INFO - epoch 22
# 2017-05-26 02:31:40,319 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:31:45,530 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 02:31:45,535 - qanta.buzzer.trainer - INFO - epoch 23
# 2017-05-26 02:32:23,028 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:32:28,533 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 02:32:28,539 - qanta.buzzer.trainer - INFO - epoch 24
# 2017-05-26 02:33:05,281 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 02:33:10,448 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 02:33:17,728 - __main__ - INFO - buzzerdev buzzes generated. Size 7587.
# 2017-05-26 02:33:17,857 - __main__ - INFO - Buzzes saved to output/buzzer/buzzerdev_buzzes_rnn_10.pkl.
# 2017-05-26 02:33:20,499 - __main__ - INFO - dev buzzes generated. Size 2089.
# 2017-05-26 02:33:20,541 - __main__ - INFO - Buzzes saved to output/buzzer/dev_buzzes_rnn_10.pkl.
# 2017-05-26 02:33:21,887 - __main__ - INFO - test buzzes generated. Size 1412.
# 2017-05-26 02:33:21,907 - __main__ - INFO - Buzzes saved to output/buzzer/test_buzzes_rnn_10.pkl.
# 2017-05-26 02:33:22,107 - __main__ - INFO - expo buzzes generated. Size 69.
# 2017-05-26 02:33:22,109 - __main__ - INFO - Buzzes saved to output/buzzer/expo_buzzes_rnn_10.pkl.
