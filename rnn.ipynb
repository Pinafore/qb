# %%
import os
import os
import sys
import random
import numpy as np
import argparse
import chainer
import pickle
from typing import List, Dict, Tuple, Optional

from qanta import logging
from qanta.config import conf
from qanta.guesser.abstract import AbstractGuesser

from qanta.buzzer import configs
from qanta.buzzer.progress import ProgressBar
from qanta.buzzer.trainer import Trainer
from qanta.buzzer.iterator import QuestionIterator
from qanta.buzzer.util import load_quizbowl, GUESSERS
from qanta.buzzer.models import MLP, RNN
from qanta.buzzer import constants as bc
from qanta.util import constants as c


log = logging.get(__name__)

N_GUESSERS = len(GUESSERS)
N_GUESSES = conf['buzzer']['n_guesses']

# %%
def dense_vector(dicts: List[List[Dict[str, float]]],
        wordvecs: List[List[np.ndarray]], step_size=1) -> List[List[float]]:

    length = len(dicts)
    prev_vec = [0.02 for _ in range(N_GUESSERS * N_GUESSES)]
    vecs = []
    for i in range(length):
        if len(dicts[i]) != N_GUESSERS:
            raise ValueError("Inconsistent number of guessers ({0}, {1}).".format(
                N_GUESSERS, len(dicts)))
        vec = []
        diff_vec = []
        isnew_vec = []
        for j in range(N_GUESSERS):
            dic = sorted(dicts[i][j].items(), key=lambda x: x[1], reverse=True)
            for guess, score in dic:
                vec.append(score)
                if i > 0 and guess in dicts[i-1][j]:
                    diff_vec.append(score - dicts[i-1][j][guess])
                    isnew_vec.append(0)
                else:
                    diff_vec.append(score) 
                    isnew_vec.append(1)
            if len(dic) < N_GUESSES:
                for k in range(max(N_GUESSES - len(dic), 0)):
                    vec.append(0)
                    diff_vec.append(0)
                    isnew_vec.append(0)
        features = [vec[0], vec[1], vec[2],
                    np.average(vec[:10]), np.average(prev_vec[:10]),
                    np.var(vec[:10]), np.var(prev_vec[:10]),
                    sum(isnew_vec[:10]),
                    isnew_vec[0], isnew_vec[1], isnew_vec[2],
                    diff_vec[0], diff_vec[1]
                    vec[0] - vec[1], vec[1] - vec[2], 
                    vec[0] / vec[1], vec[0] / prev_vec[0],
                    vec[0] - prev_vec[0], vec[1] - prev_vec[1]
                    ]

        vecs.append(features)
        prev_vec = vec
    return vecs

option2id, all_guesses = load_quizbowl()
iterators = dict()
for fold in c.BUZZER_INPUT_FOLDS:
    iterators[fold] = QuestionIterator(all_guesses[fold], option2id,
        batch_size=128, make_vector=dense_vector)
# Out:
# 2017-05-26 02:06:19,269 - qanta.buzzer.util - INFO - Merging guesser DataFrames.
# 2017-05-26 02:06:19,271 - qanta.buzzer.util - INFO - Merged buzzertrain exists, skipping.
# 2017-05-26 02:06:19,272 - qanta.buzzer.util - INFO - Merged buzzerdev exists, skipping.
# 2017-05-26 02:06:19,273 - qanta.buzzer.util - INFO - Merged dev exists, skipping.
# 2017-05-26 02:06:19,274 - qanta.buzzer.util - INFO - Merged test exists, skipping.
# 2017-05-26 02:06:19,274 - qanta.buzzer.util - INFO - Merged expo exists, skipping.
# 2017-05-26 02:06:19,275 - qanta.buzzer.util - INFO - Loading data
# 2017-05-26 02:06:19,276 - qanta.datasets.quiz_bowl - WARNING - Using QuizBowlDataset with guesser and buzzer training data, make sure you know what you are doing!
# 2017-05-26 02:06:26,631 - qanta.buzzer.util - INFO - Number of options 8247
# 2017-05-26 02:06:46,684 - qanta.buzzer.util - INFO - Loading buzzertrain guesses
# 2017-05-26 02:06:49,779 - qanta.buzzer.util - INFO - Loading buzzerdev guesses
# 2017-05-26 02:06:50,894 - qanta.buzzer.util - INFO - Loading dev guesses
# 2017-05-26 02:06:51,484 - qanta.buzzer.util - INFO - Loading test guesses
# 2017-05-26 02:06:51,506 - qanta.buzzer.util - INFO - Loading expo guesses
# 2017-05-26 02:06:53,502 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 23210/23211
# 2017-05-26 02:11:04,449 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:11:04,450 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 7586/7587
# 2017-05-26 02:12:22,338 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:12:22,339 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 2088/2089
# 2017-05-26 02:12:48,587 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:12:48,588 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 1411/1412
# 2017-05-26 02:13:03,664 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 02:13:03,665 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 68/69
# 2017-05-26 02:13:04,103 - qanta.buzzer.iterator - INFO - Finish creating batches

# %%
iterators1 = dict()
for fold in c.BUZZER_INPUT_FOLDS:
    iterators1[fold] = QuestionIterator(all_guesses[fold], option2id,
        batch_size=128)
# Out:
# 2017-05-26 05:11:41,438 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 23210/23211
# 2017-05-26 05:16:14,828 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 05:16:14,829 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 7586/7587
# 2017-05-26 05:17:43,460 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 05:17:43,461 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 2088/2089
# 2017-05-26 05:18:12,804 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 05:18:12,805 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 1411/1412
# 2017-05-26 05:18:31,469 - qanta.buzzer.iterator - INFO - Finish creating batches
# 2017-05-26 05:18:31,470 - qanta.buzzer.iterator - INFO - Creating batches
# [creat batches] (1) done: 68/69
# 2017-05-26 05:18:31,916 - qanta.buzzer.iterator - INFO - Finish creating batches

# %%
for n_hidden in [10, 25, 50, 100, 200]:
    n_hidden = 200
    cfg = configs.rnn()
    cfg.n_hidden = n_hidden
    cfg.model_name = 'rnn_1_{}'.format(n_hidden)
    cfg.model_dir = 'output/buzzer/{}.npz'.format(cfg.model_name)

    model = RNN(iterators[c.BUZZER_TRAIN_FOLD].n_input, cfg.n_hidden, N_GUESSERS + 1)
    chainer.cuda.get_device(0).use()
    model.to_gpu(0)

    trainer = Trainer(model, cfg.model_dir)
    trainer.run(iterators[c.BUZZER_TRAIN_FOLD], iterators[c.BUZZER_DEV_FOLD], 25)

    for fold in c.BUZZER_GENERATION_FOLDS:
        test_iter = iterators[fold]
        buzzes = trainer.test(test_iter)
        log.info('{0} buzzes generated. Size {1}.'.format(fold, len(buzzes)))
        buzzes_dir = bc.BUZZES_DIR.format(fold, cfg.model_name)
        with open(buzzes_dir, 'wb') as outfile:
            pickle.dump(buzzes, outfile)
        log.info('Buzzes saved to {0}.'.format(buzzes_dir))
# Out:
# 2017-05-26 05:21:40,561 - qanta.buzzer.trainer - INFO - epoch 0
# 2017-05-26 05:22:05,112 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.71
# 2017-05-26 05:22:10,283 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.76
# 2017-05-26 05:22:10,318 - qanta.buzzer.trainer - INFO - epoch 1
# 2017-05-26 05:22:41,995 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.80
# 2017-05-26 05:22:50,567 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.82
# 2017-05-26 05:22:50,605 - qanta.buzzer.trainer - INFO - epoch 2
# 2017-05-26 05:23:19,943 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.82
# 2017-05-26 05:23:34,080 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:23:34,125 - qanta.buzzer.trainer - INFO - epoch 3
# 2017-05-26 05:24:05,451 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 05:24:14,694 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:24:14,733 - qanta.buzzer.trainer - INFO - epoch 4
# 2017-05-26 05:24:46,056 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:24:54,652 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:24:54,692 - qanta.buzzer.trainer - INFO - epoch 5
# 2017-05-26 05:25:18,776 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:25:26,448 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:25:26,486 - qanta.buzzer.trainer - INFO - epoch 6
# 2017-05-26 05:26:07,219 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:26:14,854 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 05:26:14,889 - qanta.buzzer.trainer - INFO - epoch 7
# 2017-05-26 05:26:46,439 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:26:58,535 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:26:58,576 - qanta.buzzer.trainer - INFO - epoch 8
# 2017-05-26 05:27:31,778 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:27:37,080 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:27:37,119 - qanta.buzzer.trainer - INFO - epoch 9
# 2017-05-26 05:28:09,908 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:28:15,078 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:28:15,115 - qanta.buzzer.trainer - INFO - epoch 10
# 2017-05-26 05:29:01,780 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:29:15,016 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:29:15,056 - qanta.buzzer.trainer - INFO - epoch 11
# 2017-05-26 05:29:54,513 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:29:59,676 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 05:29:59,710 - qanta.buzzer.trainer - INFO - epoch 12
# 2017-05-26 05:30:25,873 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:30:33,895 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.85
# 2017-05-26 05:30:34,431 - qanta.buzzer.trainer - INFO - epoch 13
# 2017-05-26 05:31:23,615 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:31:33,685 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 05:31:33,723 - qanta.buzzer.trainer - INFO - epoch 14
# 2017-05-26 05:32:13,146 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:32:20,794 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:32:20,830 - qanta.buzzer.trainer - INFO - epoch 15
# 2017-05-26 05:32:44,952 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:32:55,576 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:32:55,614 - qanta.buzzer.trainer - INFO - epoch 16
# 2017-05-26 05:33:25,016 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:33:30,248 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.85
# 2017-05-26 05:33:30,286 - qanta.buzzer.trainer - INFO - epoch 17
# 2017-05-26 05:34:00,035 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:34:08,049 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:34:08,087 - qanta.buzzer.trainer - INFO - epoch 18
# 2017-05-26 05:34:40,595 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:34:45,815 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:34:45,852 - qanta.buzzer.trainer - INFO - epoch 19
# 2017-05-26 05:35:23,367 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:35:31,040 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 05:35:31,078 - qanta.buzzer.trainer - INFO - epoch 20
# 2017-05-26 05:35:55,583 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:36:00,801 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.85
# 2017-05-26 05:36:00,839 - qanta.buzzer.trainer - INFO - epoch 21
# 2017-05-26 05:36:27,688 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.86
# 2017-05-26 05:36:35,766 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.85
# 2017-05-26 05:36:35,803 - qanta.buzzer.trainer - INFO - epoch 22
# 2017-05-26 05:37:05,638 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.86
# 2017-05-26 05:37:17,378 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.85
# 2017-05-26 05:37:17,415 - qanta.buzzer.trainer - INFO - epoch 23
# 2017-05-26 05:38:07,091 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.86
# 2017-05-26 05:38:12,328 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.85
# 2017-05-26 05:38:12,365 - qanta.buzzer.trainer - INFO - epoch 24
# 2017-05-26 05:38:53,902 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.86
# 2017-05-26 05:39:05,182 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:39:10,444 - __main__ - INFO - buzzerdev buzzes generated. Size 7587.
# 2017-05-26 05:39:10,580 - __main__ - INFO - Buzzes saved to output/buzzer/buzzerdev_buzzes_rnn_1_200.pkl.
# 2017-05-26 05:39:20,741 - __main__ - INFO - dev buzzes generated. Size 2089.
# 2017-05-26 05:39:20,784 - __main__ - INFO - Buzzes saved to output/buzzer/dev_buzzes_rnn_1_200.pkl.
# 2017-05-26 05:39:22,111 - __main__ - INFO - test buzzes generated. Size 1412.
# 2017-05-26 05:39:22,133 - __main__ - INFO - Buzzes saved to output/buzzer/test_buzzes_rnn_1_200.pkl.
# 2017-05-26 05:39:22,336 - __main__ - INFO - expo buzzes generated. Size 69.
# 2017-05-26 05:39:22,338 - __main__ - INFO - Buzzes saved to output/buzzer/expo_buzzes_rnn_1_200.pkl.
# 2017-05-26 05:39:22,350 - qanta.buzzer.trainer - INFO - epoch 0
# 2017-05-26 05:39:46,838 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.71
# 2017-05-26 05:39:57,482 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.75
# 2017-05-26 05:39:57,519 - qanta.buzzer.trainer - INFO - epoch 1
# 2017-05-26 05:40:32,899 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.79
# 2017-05-26 05:40:38,110 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.80
# 2017-05-26 05:40:38,150 - qanta.buzzer.trainer - INFO - epoch 2
# 2017-05-26 05:41:07,538 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.82
# 2017-05-26 05:41:12,761 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.82
# 2017-05-26 05:41:12,798 - qanta.buzzer.trainer - INFO - epoch 3
# 2017-05-26 05:41:56,674 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 05:42:05,183 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.82
# 2017-05-26 05:42:05,796 - qanta.buzzer.trainer - INFO - epoch 4
# 2017-05-26 05:42:49,538 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.83
# 2017-05-26 05:42:56,319 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:42:56,357 - qanta.buzzer.trainer - INFO - epoch 5
# 2017-05-26 05:43:20,848 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:43:31,167 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:43:31,212 - qanta.buzzer.trainer - INFO - epoch 6
# 2017-05-26 05:44:13,489 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:44:21,147 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.82
# 2017-05-26 05:44:21,185 - qanta.buzzer.trainer - INFO - epoch 7
# 2017-05-26 05:44:54,708 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.84
# 2017-05-26 05:45:05,083 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:45:05,128 - qanta.buzzer.trainer - INFO - epoch 8
# 2017-05-26 05:45:39,555 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:45:54,069 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:45:54,108 - qanta.buzzer.trainer - INFO - epoch 9
# 2017-05-26 05:46:34,479 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:46:43,158 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:46:43,197 - qanta.buzzer.trainer - INFO - epoch 10
# 2017-05-26 05:47:19,050 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:47:24,269 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:47:24,307 - qanta.buzzer.trainer - INFO - epoch 11
# 2017-05-26 05:47:51,154 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:47:56,371 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.84
# 2017-05-26 05:47:56,409 - qanta.buzzer.trainer - INFO - epoch 12
# 2017-05-26 05:48:25,873 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:48:33,428 - qanta.buzzer.trainer - INFO - eval loss: 0.01  acc: 0.84
# 2017-05-26 05:48:33,465 - qanta.buzzer.trainer - INFO - epoch 13
# 2017-05-26 05:49:08,951 - qanta.buzzer.trainer - INFO - train loss: 0.00  acc: 0.85
# 2017-05-26 05:49:18,308 - qanta.buzzer.trainer - INFO - eval loss: 0.00  acc: 0.83
# 2017-05-26 05:49:18,346 - qanta.buzzer.trainer - INFO - epoch 14
